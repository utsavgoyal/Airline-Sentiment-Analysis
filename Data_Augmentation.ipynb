# %% [markdown]
# IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# READ DATA

# %%
data  = pd.read_csv("tweets.csv")
data = data.sample(frac=1).reset_index(drop=True)
data.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  568496673237929984          negative                        0.6906
# 1  568848928466198530          positive                        1.0000
# 2  570304178314190848          negative                        1.0000
# 3  568798264943902720           neutral                        1.0000
# 4  569175432702107648          positive                        1.0000
#
#            negativereason  negativereason_confidence    airline  \
# 0  Customer Service Issue                     0.3457     United
# 1                     NaN                        NaN     United
# 2              Bad Flight                     0.6784  Southwest
# 3                     NaN                        NaN      Delta
# 4                     NaN                        NaN  Southwest
#
#   airline_sentiment_gold             name negativereason_gold  retweet_count  \
# 0                    NaN      skyjumper77                 NaN              0
# 1                    NaN  MarthaH65165635                 NaN              0
# 2                    NaN     tonybrancato                 NaN              0
# 3                    NaN    Rachel_Lipson                 NaN              0
# 4                    NaN            vscof                 NaN              0
#
#                                                 text  \
# 0                     @united or did you mean 24-26?
# 1  @united since when did you get so good again! ...
# 2  @SouthwestAir my wife had been in group A in p...
# 3  @JetBlue should I be nervous about a Sunday AM...
# 4  @SouthwestAir flight 3970, bna-rdu had the mos...
#
#                    tweet_coord              tweet_created  tweet_location  \
# 0                          NaN  2015-02-19 11:45:43 -0800             NaN
# 1                          NaN  2015-02-20 11:05:27 -0800             NaN
# 2   [41.1974934, -73.76920486]  2015-02-24 11:28:06 -0800    Chappaqua NY
# 3  [38.91355311, -77.04169657]  2015-02-20 07:44:08 -0800  Washington, DC
# 4                          NaN  2015-02-21 08:42:52 -0800   Nashville, TN
#
#                 user_timezone
# 0                         NaN
# 1                         NaN
# 2  Eastern Time (US & Canada)
# 3  Eastern Time (US & Canada)
# 4                         NaN

# %% [markdown]
# EXTRACTING LABELS AND TWEETS

# %%
reviews = np.array(data['text'])
labels = np.array(data['airline_sentiment'])
reviews
# Out:
# array(['@united or did you mean 24-26?',
#        '@united since when did you get so good again!  4 transcontinental flights in 72h.  What a pleasure/relief you were.',
#        '@SouthwestAir my wife had been in group A in prev. flight but got bumped for some reason.  Alone with two kids. At least put her in group A',
#        ...,
#        '@VirginAmerica @ChrysiChrysic your assistance yesterday when u Cancelled Flightled our flight was to give us a hotel hotline  Shame on you!',
#        "@SouthwestAir Received email w/reso's to my email that isn't associated to SWA account I own with CC info for my sister. #FRAUD please DM me",
#        '@USAirways do you know what flight the pilots for 1581 are coming in on? Thanks.'],
#       dtype=object)

# %%
labels
# Out:
# array(['negative', 'positive', 'negative', ..., 'negative', 'negative',
#        'neutral'], dtype=object)

# %% [markdown]
# CLEARING PUNCTUATIONS , HYPERLINKS , AND NUMBERS

# %%
from string import punctuation
def clean(words):
  #  punctuation = '@!"#$%&'\()*+,-./:;<=>?[\\]^_`{|}~'
    nword = []
    for word in words:
        if word[0] not in punctuation and word.find('http')==-1 and any(char.isdigit() for char in word)==False:
            #word = word.replace(punctuation, ' ')
            for pun in punctuation:
                word = word.replace(pun,'')
                word = word.lower()
                word = word.replace(" s "," ")
                
            nword.append(word)
    
    return nword

# %% [markdown]
# IMPORT SPACY's ENGLISH

# %%
import spacy
spacy.prefer_gpu()
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# FUNCTION FOR LEMMATIZATION

# %%
def lemma(sentence):
    doc = nlp(sentence)
   # print(doc)
    sent = " ".join([token.lemma_ for token in doc if token.is_stop==False])
   # print(sent)
# Extract the lemma for each token and join
    return sent

# %% [markdown]
# LEMMATIZING AND CLEANING

# %%
revs = []
for re in reviews:
    #print(re)
    re = lemma(re)
    re = re.split()
    rn = clean(re)
    revs.append(rn)
    #print(rn)
revs
# Out:
# [['mean'],
#  ['good', 'transcontinental', 'flight', 'pleasure', 'relief'],
#  ['wife', 'group', 'prev', 'flight', 'get', 'bump', 'reason', 'kid', 'group'],
#  ['nervous',
#   'sunday',
#   'flight',
#   'baltimore',
#   'boston',
#   'suggestion',
#   'need',
#   'boston',
#   'monday'],
#  ['flight', 'bna', 'rdu', 'excellent', 'crew', 'today'],
#  ['discount', 'volunteer', 'firefighter'],
#  ['absolutely',
#   'horrible',
#   'customer',
#   'service',
#   'person',
#   'suppose',
#   'immediately',
#   'disconnect'],
#  ['flyingitforward',
#   'fly',
#   'port',
#   'au',
#   'prince',
#   'haiti',
#   'help',
#   'go',
#   'earthquake',
#   'relief',
#   'effort',
#   'lot'],
#  ['far', 'good', 'step', 'denver', 'stop', 'portland'],
#  ['week',
#   'take',
#   'money',
#   'leave',
#   'strand',
#   'hour',
#   'home',
#   'rent',
#   'car',
#   'help'],
#  ['love', 'capt', 'joe', 'flight', 'bos', 'sfo', 'fun'],
#  ['seriously', 'doubt', 'sit', 'inside', 'gate'],
#  ['inconvenience', 'disaster', 'phone', 'bill', 'refuse', 'pay'],
#  ['flight', 'arrive', 'follow', 'flight'],
#  ['inform', 'hour', 'delay', 'pick', 'phone', 'flight'],
#  ['flight',
#   'delay',
#   'hour',
#   'la',
#   'mechanical',
#   'problem',
#   'handle',
#   'like',
#   'pro',
#   'toss',
#   'free',
#   'drink'],
#  ['hire',
#   'extra',
#   'customer',
#   'service',
#   'rep',
#   'minute',
#   'wait',
#   'time',
#   'ask',
#   'question',
#   'fly',
#   'airline',
#   'thank'],
#  ['thank',
#   'agent',
#   'boarding',
#   'atl',
#   'aus',
#   'leave',
#   'wallet',
#   'inbound',
#   'find'],
#  ['email'],
#  ['flight', 'wifi', 'promise', 'ground', 'crew', 'anotherdisappointment'],
#  ['stuck',
#   'nyc',
#   'flight',
#   'cancel',
#   'flightled',
#   'day',
#   'row',
#   'long',
#   'wait',
#   'time',
#   'phone',
#   'run',
#   'swa',
#   'help'],
#  ['time', 'count'],
#  ['people',
#   'awesome',
#   'work',
#   'long',
#   'hour',
#   'easy',
#   'sorry',
#   'twitter',
#   'help',
#   'ppl'],
#  ['u',
#   'hate',
#   'delay',
#   'u',
#   'amp',
#   'hold',
#   'hostage',
#   'goingforgreatnessfail'],
#  ['got'],
#  ['look', 'forward', 'finally'],
#  ['boom'],
#  ['hear',
#   'today',
#   'flight',
#   'tomorrow',
#   'arrive',
#   'home',
#   'pm',
#   'mean',
#   'day',
#   'work'],
#  ['follow', 'dm', 'thx'],
#  ['hold',
#   'min',
#   'attempt',
#   'receipt',
#   'show',
#   'change',
#   'fee',
#   'upcoming',
#   'flight',
#   'help'],
#  ['flight', 'buffalo', 'flight', 'cancel', 'flightled'],
#  ['purchase', 'ticket', 'united', 'card', 'priority', 'boarding'],
#  ['flight'],
#  ['lose',
#   'bag',
#   'amp',
#   'min',
#   'hold',
#   'tell',
#   'eventually',
#   'bag',
#   'completely',
#   'unacceptable'],
#  ['try', 'book', 'reservation', 'system', 'let', 'day', 'ridiculous'],
#  ['sure',
#   'sincere',
#   'apology',
#   'disappointing',
#   'customer',
#   'perspective',
#   'want',
#   'loyal',
#   'customer',
#   'option'],
#  ['try', 'check', 'min', 'flight', 'min', 'stonewall', 'employee'],
#  ['ba', 'flight', 'access', 'lounge', 'ord', 'hrs'],
#  ['hold', 'hour', 'minute', 'cust', 'service', 'help'],
#  ['literally', 'bad', 'flying', 'experience', 'life', 'fly', 'lot'],
#  ['navy',
#   'sister',
#   'flight',
#   'cancld',
#   'agent',
#   'call',
#   'hold',
#   'amp',
#   'discnct',
#   'help'],
#  ['shit', 'get', 'to', 'stop', 'rt', 'fleet', 'fleek'],
#  ['flight',
#   'love',
#   'redeem',
#   'point',
#   'little',
#   'year',
#   'old',
#   'historical',
#   'limit'],
#  ['great',
#   'callback',
#   'agent',
#   'disconnect',
#   'try',
#   'hold',
#   'wait',
#   'connectfor'],
#  ['fix',
#   'engine',
#   'flight',
#   'spend',
#   'night',
#   'airport',
#   'fly',
#   'home',
#   'tomorrow'],
#  ['thank',
#   'home',
#   'msy',
#   'tsa',
#   'precheck',
#   'agent',
#   'direct',
#   'people',
#   'photo',
#   'scan',
#   'rude',
#   'grab',
#   'push',
#   'child'],
#  ['possible', 'cancel', 'flight', 'reservation', 'online'],
#  ['bad',
#   'customer',
#   'service',
#   'provide',
#   'answer',
#   'drive',
#   'clt',
#   'airport',
#   'rude',
#   'amp',
#   'unacceptable',
#   'fail'],
#  ['live',
#   'person',
#   'speak',
#   'day',
#   'dividend',
#   'miles',
#   'wrongfully',
#   'take',
#   'mile',
#   'account'],
#  ['gold',
#   'force',
#   'pay',
#   'upgrade',
#   'open',
#   'seat',
#   'offer',
#   'gold',
#   'sapphire'],
#  ['bag', 'miss'],
#  ['ewr',
#   'dfw',
#   'stop',
#   'bna',
#   'refuel',
#   'bad',
#   'weather',
#   'try',
#   'plane',
#   'closer',
#   'dfw',
#   'cancel',
#   'flight'],
#  ['fleet', 'fleek', 'wtf', '😂', '😂', '😂', '😂'],
#  ['plane', 'hope', 'well', 'luck', 'return', 'flight', 'sunday'],
#  ['thank',
#   'want',
#   'fix',
#   'line',
#   'customer',
#   'care',
#   'team',
#   'currently',
#   'respond',
#   'inquiry',
#   'business',
#   'day'],
#  ['social', 'agency', 'nice', 'thing', 'fleet', 'fleek'],
#  ['wife',
#   'land',
#   'dc',
#   'ago',
#   'luggage',
#   'tell',
#   'b',
#   'deliver',
#   'hotel',
#   'pm',
#   'pm',
#   'luggage'],
#  ['fantastic', 'good', 'flight', 'service'],
#  ['stressful',
#   'morning',
#   'pay',
#   'check',
#   'bag',
#   'lax',
#   'madhouse',
#   'lot',
#   'angry',
#   'customer',
#   'yike'],
#  ['comenity', 'bank', 'joke', 'change', 'constant', 'problem', 'bank'],
#  ['reconsider',
#   'usairway',
#   'acquisition',
#   'flight',
#   'aa',
#   'gold',
#   'flyer',
#   'insult',
#   'attendant',
#   'hang',
#   'jacket'],
#  ['southern',
#   'hospitality',
#   'luggage',
#   'delivery',
#   'service',
#   'sav',
#   'awful',
#   'great',
#   'deliver',
#   'promise',
#   'luggage'],
#  ['service', 'suck'],
#  ['pilot',
#   'start',
#   'flight',
#   'announce',
#   'arrival',
#   'gatwick',
#   'heathrow',
#   'moment',
#   'concern',
#   'aboard'],
#  ['flight', 'brother', 'rebooke', 'able', 'info', 'phone', 'pass', 'club'],
#  ['thank'],
#  ['continue', 'amazed', 'amazing', 'customer', 'service', 'thank', 'swa'],
#  ['come',
#   'crew',
#   'travel',
#   'flight',
#   'get',
#   'well',
#   'seat',
#   'stick',
#   'check',
#   'bag',
#   'crew',
#   'bag',
#   'get',
#   'flight'],
#  ['serve',
#   'rubber',
#   'pasta',
#   'cover',
#   'sauce',
#   'taste',
#   'like',
#   'plastic',
#   'food',
#   'human',
#   'consumption',
#   'anymore'],
#  ['beware',
#   'barklays',
#   'bank',
#   'terrible',
#   'cust',
#   'service',
#   'assist',
#   'know',
#   'badly',
#   'write',
#   'bookin',
#   'english'],
#  ['nonstop', 'sjc', 'bna', 'sfo', 'oak', 'pleaseeeeee', 'thank'],
#  ['local',
#   'united',
#   'number',
#   'malaysia',
#   'local',
#   'united',
#   'airlines',
#   'kuala',
#   'lumpur',
#   'kul'],
#  ['type',
#   'person',
#   'customer',
#   'day',
#   'fly',
#   'time',
#   'year',
#   'amp',
#   'flight',
#   'attendant'],
#  ['absolutely'],
#  ['point', 'flight', 'past', 'week', 'suck', 'shit'],
#  ['time',
#   'try',
#   'line',
#   'disconnected',
#   'b',
#   'c',
#   'system',
#   'say',
#   'call',
#   'glad',
#   'screw',
#   'matter'],
#  ['check', 'system', 'have', 'trouble', 'check', 'flight', 'depart', 'hr'],
#  ['let',
#   'chat',
#   'flight',
#   'bwi',
#   'carolina',
#   'area',
#   'girl',
#   'break',
#   'resort',
#   'usair',
#   '😖',
#   'day'],
#  ['hate'],
#  ['call',
#   'monday',
#   'customer',
#   'relation',
#   'disappointed',
#   'treat',
#   'customer',
#   'service'],
#  ['hour',
#   'ugh',
#   'voucher',
#   'inexcusable',
#   'esp',
#   'pre',
#   'flight',
#   'check',
#   'ok'],
#  ['airline', 'tell', 'luggage', 'hour', 'away', 'destination', 'day'],
#  ['send', 'dm', 'detail'],
#  ['wait'],
#  ['need',
#   'help',
#   'flight',
#   'weather',
#   'funeral',
#   'tough',
#   'combination',
#   'hold',
#   'hour'],
#  ['wifi',
#   'tell',
#   'family',
#   'go',
#   'to',
#   'late',
#   'flight',
#   'cause',
#   'sit',
#   'ground',
#   'plane',
#   'past',
#   'hour'],
#  ['amazing',
#   'day',
#   'delay',
#   'hrs',
#   'bc',
#   'freeze',
#   'plane',
#   'sit',
#   'gate',
#   'plane',
#   'min',
#   'wait'],
#  ['beginning',
#   'feb',
#   'call',
#   'united',
#   'say',
#   'send',
#   'voucher',
#   'mail',
#   'get',
#   'tiredofwaiting'],
#  ['worry', 'go', 'to', 'share', 'row', '😁'],
#  ['stick',
#   'cae',
#   'need',
#   'reflight',
#   'booking',
#   'problem',
#   'flight',
#   'possibly',
#   'dm',
#   'info'],
#  ['try', 'call', 'time', 'past', 'day', 'get', 'tell', 'help'],
#  ['make',
#   'great',
#   'impression',
#   'flight',
#   'minute',
#   'boarding',
#   'gate',
#   'agent',
#   'assign',
#   'seat'],
#  ['hold',
#   'plane',
#   'hourdelay',
#   'multipledooropeningandclosing',
#   'dangerofgettingsnowedin'],
#  ['stick', 'tarmac', 'min', 'phl', 'wait', 'load', 'baggage', 'ridiculous'],
#  ['delivery', 'service', 'use', 'like'],
#  ['yes', 'soon', 'moment', 'gather', 'thought'],
#  ['check', 'website', 'airport'],
#  ['thank',
#   'charge',
#   'switch',
#   'cancel',
#   'flightle',
#   'flight',
#   'pretty',
#   'nice',
#   'stillmakingmepoorthough'],
#  ['fort',
#   'launder',
#   'dale',
#   'gate',
#   'agent',
#   'switch',
#   'flight',
#   'early',
#   'flight',
#   'phone',
#   'ridiculous'],
#  ['kurt',
#   'crew',
#   'amazing',
#   'today',
#   'son',
#   'birthday',
#   'kindness',
#   'hope',
#   'fly',
#   'soon'],
#  ['love', 'dm', 'twitter', 'app', 'say', 'follow'],
#  ['thank',
#   'info',
#   'try',
#   'luck',
#   'flight',
#   'dep',
#   'today',
#   'need',
#   'change',
#   'tomorrow',
#   'thursday'],
#  ['like', 'airplane', 'fiousairway', '💁'],
#  ['hi', 'attach', 'aa', 'ff', 'reservation', 'thansk'],
#  ['guy',
#   'bad',
#   'fly',
#   'philadelphia',
#   'jetway',
#   'available',
#   'time',
#   'planepisspoor'],
#  ['thank',
#   'margo',
#   'houston',
#   'bush',
#   'intercontinental',
#   'get',
#   'home',
#   'earlier'],
#  ['kudos',
#   'captain',
#   'crew',
#   'handle',
#   'fustrated',
#   'people',
#   'deal',
#   'preventable',
#   'issue',
#   'shortcoming',
#   'maint'],
#  ['ceo',
#   'battle',
#   'appease',
#   'passenger',
#   'wall',
#   'street',
#   'waterbury',
#   'republican',
#   'american'],
#  ['accord',
#   'flight',
#   'attendant',
#   'husband',
#   'talk',
#   'english',
#   'fact',
#   'understand',
#   'talk'],
#  ['website',
#   'seriously',
#   'horrible',
#   'center',
#   'make',
#   'tempting',
#   'fly',
#   'sodone'],
#  ['delta', 'flight', 'lax', 'compensate', 'rental', 'car'],
#  ['come',
#   'work',
#   'today',
#   'u',
#   'pilot',
#   'flight',
#   'attendant',
#   'answer',
#   'phone',
#   'fly'],
#  ['call', 'service', 'line', 'hang', 'awesome', 'sarcasm'],
#  ['flight',
#   'cancel',
#   'flighted',
#   'opportunity',
#   'rebook',
#   'flight',
#   'evening',
#   'pass'],
#  ['flight', 'dca', 'need', 'change', 'asap', 'help'],
#  ['share', 'come'],
#  ['tell', 'file', 'claim', 'clothing', 'purchase'],
#  ['non', 'revs', 'right'],
#  ['checkin', 'lame', 'business', 'seat', 'broad', 'shoulder', 'haha'],
#  ['love'],
#  ['customerservice', 'bad', 'bad', 'weather', 'awful'],
#  ['closepwcs',
#   'tweet',
#   '🙏',
#   '🙏',
#   '❤',
#   '️',
#   'fly',
#   'jetblue',
#   'time',
#   'btw',
#   '😏'],
#  ['plan', 'start', 'fly', 'direct', 'dal', 'las'],
#  ['instead', 'bourbon', 'street', 'quiet', 'plane', 'savethediagonal'],
#  ['mco', 'thank'],
#  ['flight',
#   'amp',
#   'flight',
#   'attendant',
#   'flight',
#   'freaky',
#   'coincidence',
#   'plus',
#   'great'],
#  ['family',
#   'friend',
#   'colleague',
#   'fly',
#   'usair',
#   'bad',
#   'weather',
#   'happen',
#   'good',
#   'airline',
#   'communicate',
#   'better'],
#  ['headphone', 'jack', 'work', 'flight'],
#  ['yeah', 'know', 'spend', 'dollar', 'ticket', 'price', 'go', 'week'],
#  ['have',
#   'check',
#   'bag',
#   'wait',
#   'min',
#   'bag',
#   'come',
#   'baggage',
#   'claim',
#   'thank',
#   'waste',
#   'time'],
#  ['flight',
#   'philly',
#   'mia',
#   'bwahahaha',
#   'delay',
#   'hrs',
#   'air',
#   'min',
#   'turn',
#   'usairwaysfail'],
#  ['way',
#   'voice',
#   'customer',
#   'pay',
#   'service',
#   'satisfactorily',
#   'deliver',
#   'justsayin'],
#  ['time',
#   'check',
#   'bag',
#   'airline',
#   'confident',
#   'wear',
#   'clothe',
#   'day',
#   'prove',
#   'wrong'],
#  ['flt',
#   'time',
#   'board',
#   'departure',
#   'b',
#   'c',
#   'wait',
#   'new',
#   'crew',
#   'subterfuge'],
#  ['nice', 'try', 'apply', 'philly'],
#  ['fly',
#   'soon',
#   'nyc',
#   'airline',
#   'airline',
#   'fly',
#   '😊',
#   '😊',
#   '😊',
#   '✈',
#   '️',
#   '✈',
#   '️',
#   '✈',
#   '️'],
#  ['amazing',
#   'hospitality',
#   'helpfulness',
#   'anthony',
#   'lastella',
#   'great',
#   'staff',
#   '👏',
#   '👏',
#   '👏',
#   '✈',
#   '️',
#   'def',
#   'fly',
#   'unite'],
#  ['employee',
#   'call',
#   'time',
#   'flight',
#   'crew',
#   'finish',
#   'maintenance',
#   'depart'],
#  ['thank', 'great', 'tool'],
#  ['tight', 'connection', 'charlotte', 'frankfurt'],
#  ['right', 'good', 'catch', 'mechanical', 'failure', 'bad', 'blanket', 'ok'],
#  ['dad',
#   'vacation',
#   'sxm',
#   'get',
#   'delay',
#   'day',
#   'shoddy',
#   'service',
#   'early',
#   'fll',
#   'gt',
#   'sxm',
#   'flight',
#   'try',
#   'hep'],
#  ['character', 'describe', 'inconsiderate', 'employee'],
#  ['bad', 'customer', 'service', 'let', 'people', 'assault', 'flight'],
#  ['hey', 'southwest', 'wanna', 'guy', 'lot', 'well', 'jet', 'blue'],
#  ['dtv',
#   'not',
#   'work',
#   'pilot',
#   'late',
#   'flight',
#   'will',
#   'not',
#   'let',
#   'old',
#   'fly',
#   'pay',
#   'upgrade',
#   'unitedsuck'],
#  ['awesome', 'thank', 'hold'],
#  ['access',
#   'dividend',
#   'miles',
#   'week',
#   'automate',
#   'phone',
#   'keep',
#   'tell',
#   'late',
#   'flightr',
#   'frustrated',
#   'livepersonplease'],
#  ['seriously', 'flight', 'past', 'day', 'delay', 'single', 'terrible'],
#  ['appreciate', 'response', 'speak', 'mco', 'response', 'idk', 'mean'],
#  ['thank',
#   'person',
#   'houston',
#   'flight',
#   'route',
#   'newark',
#   'nj',
#   'go',
#   'sfo'],
#  ['receive', 'confirmation', 'email', 'confirm', 'ticket', 'flight'],
#  ['call',
#   'btv',
#   'desk',
#   'information',
#   'exist',
#   'system',
#   'easy',
#   'customer',
#   'access'],
#  ['big',
#   'thank',
#   'team',
#   'family',
#   'emerg',
#   'day',
#   'ticket',
#   'experience',
#   'excellent',
#   'time',
#   'fly'],
#  ['cancel',
#   'flightle',
#   'flight',
#   'tomorrow',
#   'tell',
#   'want',
#   'rebook',
#   'help',
#   'book',
#   'new',
#   'flight'],
#  ['oh',
#   'irony',
#   'dog',
#   'spot',
#   'bark',
#   'wait',
#   'area',
#   'right',
#   'send',
#   'cocktail',
#   'coupon',
#   'stat'],
#  ['need',
#   'assistance',
#   'incompetence',
#   'need',
#   'reschedule',
#   'connection',
#   'fly'],
#  ['guess', 'respond', 'compliment', 'sorry', 'thinkof'],
#  ['check',
#   'app',
#   'say',
#   'flight',
#   'move',
#   'day',
#   'explanation',
#   'answer',
#   'number'],
#  ['contacted',
#   'yesterday',
#   'tell',
#   'suggest',
#   'email',
#   'compensation',
#   'cust',
#   'service'],
#  ['stop', 'madness', 'rt', 'fleet', 'fleek'],
#  ['actually',
#   'say',
#   'fraud',
#   'issue',
#   'resolve',
#   'issue',
#   'new',
#   'ticket',
#   'phone'],
#  ['wait', 'connect', 'agent'],
#  ['set', 'figure', 'baggage', 'office'],
#  ['thank'],
#  ['thank',
#   'effort',
#   'early',
#   'complaint',
#   'refund',
#   'lose',
#   'business',
#   'day',
#   'tomorrow'],
#  ['try',
#   'online',
#   'flight',
#   'booking',
#   'problems',
#   'way',
#   'barbados',
#   'will',
#   'not',
#   'let',
#   'say',
#   'need',
#   'barbados',
#   'cc'],
#  ['care', 'person', 'walk', 'away', 'complain', 'man', 'lax', 'club'],
#  ['overload',
#   'small',
#   'plane',
#   'extra',
#   'baggage',
#   'poor',
#   'execution',
#   'minute',
#   'delay'],
#  ['great',
#   'flight',
#   'cabo',
#   'week',
#   'family',
#   'smoothflight',
#   'frequentflyer'],
#  ['guy', 'rid', 'hip', 'hop', 'station', 'sirius', 'xm'],
#  ['airlines',
#   'cancel',
#   'flights',
#   'oc',
#   'fll',
#   'flight',
#   'today',
#   'switch',
#   'notice',
#   'apology',
#   'fly',
#   'unitedairlines'],
#  ['concerned'],
#  ['problem',
#   'apology',
#   'help',
#   'result',
#   'matter',
#   'prove',
#   'impossible',
#   'find',
#   'interested'],
#  ['wtf',
#   'pay',
#   'direct',
#   'flight',
#   'purpose',
#   'stop',
#   'fuel',
#   'exhaust',
#   'frequent',
#   'flier',
#   'inconvenience'],
#  ['amp',
#   'staff',
#   'rude',
#   'amp',
#   'ignore',
#   'passenger',
#   'dont',
#   'think',
#   'accept',
#   'reason'],
#  ['thank', 'completely', 'thing', 'right'],
#  ['great', 'week', '🌞', '✈'],
#  ['wife',
#   'need',
#   'help',
#   'strand',
#   'chicago',
#   'monday',
#   'will',
#   'find',
#   'bag',
#   'volume',
#   'high'],
#  ['slow',
#   'boarding',
#   'process',
#   'experience',
#   'rude',
#   'customer',
#   'service',
#   'agent'],
#  ['able', 'dm', 'confirmation', 'number'],
#  ['despicable',
#   'speak',
#   'diff',
#   'people',
#   'amp',
#   'tell',
#   'different',
#   'claim',
#   'need',
#   'bag'],
#  ['claim',
#   'w',
#   'customer',
#   'protection',
#   'notify',
#   'customer',
#   'delay',
#   'cancel',
#   'flightlations',
#   'diversion',
#   'nottrue'],
#  ['follow', 'dm'],
#  ['true', 'stop', 'make', 'excuse', 'overbook', 'crappy', 'plane'],
#  ['rebooke',
#   'oma',
#   'mile',
#   'destination',
#   'spotty',
#   'customer',
#   'service',
#   'staff',
#   'stressor',
#   'come',
#   'business'],
#  ['bad', 'experience', 'life'],
#  ['cheat',
#   'go',
#   'horribly',
#   'wrong',
#   'promise',
#   'will',
#   'stray',
#   'anymore',
#   'talk'],
#  ['bag', 'turn', 'thank', 'useless', 'centre', 'useless', 'website'],
#  ['suprise',
#   'new',
#   'vanity',
#   'kit',
#   'set',
#   'frequent',
#   'traveller',
#   '😀',
#   'thank',
#   'aa'],
#  ['awesome', 'fly', 'sat', 'morning', 'way', 'correct', 'bill'],
#  ['listen',
#   'flight',
#   'take',
#   'house',
#   'kick',
#   'flight',
#   'booking',
#   'problems',
#   'flight',
#   'tomorrow',
#   'iceday'],
#  ['dm'],
#  ['luv', 'companion', 'pass'],
#  ['thank', 'good', 'work'],
#  ['min',
#   'response',
#   'time',
#   'impressed',
#   'official',
#   'trueblue',
#   'jetblue',
#   'get',
#   'social'],
#  ['ceo', 'battle', 'wall', 'st', 'flyer'],
#  ['staff', 'contract', 'pvd', 'fail', 'big', 'time', 'tonight'],
#  ['guy',
#   'lose',
#   'luggage',
#   'suppose',
#   'flight',
#   'highly',
#   'disappointed',
#   'med',
#   'clothe'],
#  ['okay',
#   'thank',
#   'tweet',
#   'earlier',
#   'hr',
#   'ago',
#   'say',
#   'win',
#   'amp',
#   'send',
#   'dm',
#   'delete'],
#  ['guy', 'follow', 'dm'],
#  ['appreciate', 'follow', 'fly', 'reason'],
#  ['say', 'need', 'supervisor', 'wait', 'supervisor', 'hang'],
#  ['service',
#   'credit',
#   'voucher',
#   'receive',
#   'tv',
#   'work',
#   'accept',
#   'flight',
#   'pillow'],
#  ['jetblue',
#   'travel',
#   'maimi',
#   'year',
#   'guy',
#   'not',
#   'maimi',
#   '😭',
#   'not',
#   'guy',
#   'maimi'],
#  ['thank'],
#  ['thank'],
#  ['houston', 'hub', 'aa', 't', 'employee', 'bag', 'pa', 'oops', 'problem'],
#  ['captain',
#   'flight',
#   'phx',
#   'phl',
#   'tonight',
#   'hilarious',
#   'greeting',
#   'pointy',
#   'end',
#   'airplane',
#   'haha',
#   'thank'],
#  ['screw',
#   'deal',
#   'mechanical',
#   'failure',
#   'maui',
#   'san',
#   'francisco',
#   'poor',
#   'communication',
#   'bad',
#   'help',
#   'get',
#   'connection'],
#  ['folk',
#   'executive',
#   'platinum',
#   'desk',
#   'great',
#   'pro',
#   'understand',
#   'displeasure',
#   'change',
#   'fee',
#   'switch',
#   'sw'],
#  ['status', 'itinerary', 'say', 'request', 'red', 'mean'],
#  ['great',
#   'crew',
#   'flight',
#   'phx',
#   'yvr',
#   'tonight',
#   'friendly',
#   'efficient',
#   'awesome',
#   'job'],
#  ['flight', 'depart', 'enroute'],
#  ['tell', 'cancel', 'flightle', 'flight', 'vs', 'delay'],
#  ['shame',
#   'choose',
#   'united',
#   'difference',
#   'reunite',
#   'age',
#   'friend',
#   'see',
#   'poorservice'],
#  ['bummer', 'understand', 'business', 'deal', 'thank', 'answer', 'sad'],
#  ['ceo',
#   'battle',
#   'appease',
#   'passenger',
#   'wall',
#   'street',
#   'lake',
#   'wylie',
#   'pilot'],
#  ['nice',
#   'people',
#   'flight',
#   'chicago',
#   'thank',
#   'david',
#   'deane',
#   'amp',
#   'norma',
#   'sedholm',
#   'make',
#   'feel',
#   'comfortable',
#   '✈',
#   '️',
#   '✈',
#   '️',
#   '✈',
#   '️',
#   '✈',
#   '️',
#   '✈',
#   '️',
#   '✈',
#   '️',
#   '✈',
#   '️'],
#  ['quality', 'work', 'go'],
#  ['show',
#   'flight',
#   'way',
#   'try',
#   'home',
#   'page',
#   'book',
#   'roundtrip',
#   'available'],
#  ['thank',
#   'have',
#   'pilot',
#   'flight',
#   'strand',
#   'houston',
#   'tonight',
#   'airlines',
#   'absolute',
#   'bad'],
#  ['chair', 'selfie', 'look', 'flawless', 'proud', 'phl', 'crew', 'blueheros'],
#  ['msp',
#   'employee',
#   'try',
#   'check',
#   'line',
#   'crazy',
#   'miss',
#   'plane',
#   'sure',
#   'thank',
#   'employee'],
#  ['thank'],
#  ['thank',
#   'helpful',
#   'understand',
#   'reduce',
#   'price',
#   'seat',
#   'sell',
#   'check',
#   'priority',
#   'certificate'],
#  ['employee', 'racist'],
#  ['frustrated',
#   'see',
#   'seat',
#   'avail',
#   'online',
#   'pref',
#   'alt',
#   'flight',
#   'unable',
#   'book',
#   'online',
#   'lose',
#   'seat',
#   'hr',
#   'phone',
#   'hold'],
#  ['pls',
#   'send',
#   'tech',
#   'baggage',
#   'office',
#   'poor',
#   'guy',
#   'try',
#   'print',
#   'claim',
#   'amp',
#   'need',
#   'home',
#   'upgrade',
#   'printer',
#   'mfp'],
#  ['protect',
#   'flight',
#   'gate',
#   'agent',
#   'kerry',
#   'las',
#   'excellent',
#   'job',
#   'get',
#   'destination',
#   'today',
#   'thank'],
#  ['insensitive',
#   'foodallergies',
#   'life',
#   'threaten',
#   'unsolicited',
#   'uneducated',
#   'opinion',
#   'inappropriate',
#   'reckless',
#   'amp',
#   'dangerous'],
#  ['thx', 'response', 'finally', 'get', 'min', 'wait', 'talk'],
#  ['past',
#   'yrs',
#   'earn',
#   'list',
#   'status',
#   'promo',
#   'fly',
#   'rnd',
#   'trip',
#   'month',
#   'option',
#   'loyal'],
#  ['glad',
#   'spend',
#   'hour',
#   'try',
#   'track',
#   'basic',
#   'information',
#   'available'],
#  ['link', 'flyfi'],
#  ['respond',
#   'e',
#   'mail',
#   'facebook',
#   'msg',
#   'wate',
#   'ticket',
#   'get',
#   'angry',
#   'disappointed'],
#  ['useless',
#   'response',
#   'need',
#   'function',
#   'wheelchair',
#   'customer',
#   'care',
#   'form',
#   'fill'],
#  ['strand',
#   'chicago',
#   'ohare',
#   'hour',
#   'chance',
#   'cracker',
#   'jack',
#   'service',
#   'team',
#   'provide',
#   'meal'],
#  ['yes',
#   'file',
#   'claim',
#   'soon',
#   'carousel',
#   'stop',
#   'bag',
#   'get',
#   'email',
#   'find',
#   'sche',
#   'delivery'],
#  ['round', 'trip', 'week', 'trueblue'],
#  ['contact', 'email', 'customer', 'complaint'],
#  ['kill', 'delay', 'sandiego', 'sf', 'ugh'],
#  ['small',
#   'degree',
#   'self',
#   'interest',
#   'route',
#   'time',
#   'year',
#   'amp',
#   'hate',
#   'situation'],
#  ['clt',
#   'baggage',
#   'crew',
#   'deserve',
#   'kudo',
#   'run',
#   'connection',
#   'bag',
#   'customerservice'],
#  ['book', 'hotel', 'twice', 'ahhhhh'],
#  ['expect'],
#  ['pls', 'follow', 'dm'],
#  ['delay', 'need', 'extra', 'min', 'appreciate', 'little', 'help', 'week'],
#  ['understand',
#   'resort',
#   'twitter',
#   'help',
#   'available',
#   'gate',
#   'occur',
#   'phone',
#   'afterward'],
#  ['start', 'flight', 'chicago', 'evansville', 'avgeek'],
#  ['pull',
#   'runway',
#   'make',
#   'new',
#   'friend',
#   'seat',
#   'mate',
#   'thank',
#   'response',
#   'cb'],
#  ['flight'],
#  ['good', 'know', 'execution'],
#  ['unable', 'book', 'travel', 'right', 'website', 'app', 'help'],
#  ['time',
#   'direct',
#   'flight',
#   'jfk',
#   'pitt',
#   'official',
#   'jetblue',
#   'terminal',
#   'new',
#   'york',
#   '…'],
#  ['not',
#   'help',
#   'frustrate',
#   'hour',
#   'u',
#   'end',
#   'disconnection',
#   'answer',
#   'especially',
#   'div',
#   'pref',
#   'member'],
#  ['want', 'crazy', 'ask', 'twice'],
#  ['clue', 'place', 'stay'],
#  ['try', 'day', 'hang', 'prompt'],
#  ['crew',
#   'member',
#   'deal',
#   'orlando',
#   'incredibly',
#   'rude',
#   'actually',
#   'pretty',
#   'disgusted',
#   'jetblue',
#   'right'],
#  ['sure', 'business', 'airline', 'travel', 'kathryn', 'sotelo'],
#  ['frustratingly',
#   'delay',
#   'happen',
#   'gate',
#   'onboard',
#   'aircraft',
#   'head',
#   'advance'],
#  ['get',
#   'phishe',
#   'email',
#   'claim',
#   'southwest',
#   'forward',
#   'like',
#   'investigate'],
#  ['travel',
#   'bank',
#   'credit',
#   'issue',
#   'company',
#   'fraud',
#   'acquire',
#   'credit',
#   'family',
#   'friend',
#   'charles',
#   'kravitz',
#   'account'],
#  ['flight', 'open', 'middle', 'seat', 'want', 'sit', 'policy'],
#  ['buy',
#   'ticket',
#   'price',
#   'publish',
#   'mistake',
#   'get',
#   'email',
#   'indicate',
#   'united',
#   'cancelled',
#   'flightled',
#   'ticket'],
#  ['confused', 'agent', 'direct', 'website', 'delays', 'work'],
#  ['sis',
#   'month',
#   'old',
#   'nephew',
#   'night',
#   'flight',
#   'mega',
#   'delay',
#   'evening',
#   'start',
#   'w',
#   'delay'],
#  ['educate',
#   'bohol',
#   'w',
#   'volunteer',
#   'staff',
#   'help',
#   'kid',
#   'buy',
#   'plane',
#   'ticket',
#   'help'],
#  ['awesome',
#   'flight',
#   'dallas',
#   'ny',
#   'virgin',
#   'america',
#   'refuse',
#   'bc',
#   'child',
#   'peanut',
#   'allergy',
#   'u',
#   'guy',
#   'thank',
#   '👍',
#   '😊'],
#  ['pleasantly',
#   'surprised',
#   'quality',
#   'service',
#   'flight',
#   'fly',
#   'lga',
#   'cle',
#   'den',
#   'friendly',
#   'crew',
#   'love',
#   'concept',
#   'byod',
#   'worksnicely'],
#  ['strive',
#   'customer',
#   'centric',
#   'communication',
#   'advertising',
#   'customer',
#   'journey',
#   'etc',
#   'anamarketer'],
#  ['bad', 'airline'],
#  ['rebooke',
#   'split',
#   'different',
#   'flight',
#   'pilot',
#   'run',
#   'hour',
#   'frustrating'],
#  ['pullin', 'sh', 'delay', 'flight', 'smh'],
#  ['fail',
#   'week',
#   'iah',
#   'intl',
#   'trip',
#   'delta',
#   'small',
#   'ual',
#   'flight',
#   'lax',
#   'book'],
#  ['time',
#   'rant',
#   'delay',
#   'flight',
#   'forget',
#   'luggage',
#   'delay',
#   'tarmac',
#   'moment',
#   'love',
#   'united'],
#  ['u',
#   'guy',
#   'cancel',
#   'flight',
#   'bna',
#   'flight',
#   'amp',
#   'bother',
#   'alert',
#   'passenger',
#   'give'],
#  ['worry', 'initiative', 'arrive', 'earlier', 'plan'],
#  ['thank',
#   'take',
#   'care',
#   'drink',
#   'flight',
#   'entertainment',
#   'work',
#   'goodcustomerservice'],
#  ['destinationdragons', 'scavenger', 'hunt', 'rule'],
#  ['thank',
#   'reply',
#   'fill',
#   'form',
#   'submit',
#   'request',
#   'good',
#   'know',
#   'pay',
#   'attention'],
#  ['say', 'open'],
#  ['try', 'check', 'tomorrow', 'flight', 'website', 'keep', 'timing'],
#  ['amen'],
#  ['merging', 'mile', 'complete', 'month'],
#  ['premium', 'wifi', 'pay', 'decent', 'slow', 'fi'],
#  ['nice',
#   'try',
#   'gate',
#   'make',
#   'traveler',
#   'traveler',
#   'bag',
#   'size',
#   'guide',
#   'oversell',
#   'sorry',
#   'minefit'],
#  ['reservation',
#   'tomorrow',
#   'morning',
#   'try',
#   'night',
#   'bc',
#   'flight',
#   'go',
#   'jfk',
#   'list',
#   'ctg'],
#  ['despite',
#   'fact',
#   'answer',
#   'people',
#   'twitter',
#   'mundane',
#   'qs',
#   'refuse',
#   'answer'],
#  ['lose', 'time'],
#  ['dear', 'virgin', 'customer', 'strand', 'sf', 'day', 'amp', 'accommodate'],
#  ['night', 'severe', 'weather', 'need', 'change', 'fair', 'go'],
#  ['joanne',
#   'san',
#   'diego',
#   'staff',
#   'phenomenal',
#   'girl',
#   'raise',
#   'handle',
#   'flightnightmare',
#   'better'],
#  ['thank',
#   'quick',
#   'response',
#   'aa',
#   'usually',
#   'fantastic',
#   'customer',
#   'service',
#   'shocked'],
#  ['sister',
#   'family',
#   'drive',
#   'mile',
#   'accommodate',
#   'rebook',
#   'timely',
#   'manner',
#   'horrible'],
#  ['flight',
#   'today',
#   'phl',
#   'dal',
#   'cancel',
#   'flightled',
#   'min',
#   'hold',
#   'rebooke',
#   'tomorrow',
#   'flight',
#   'cancel',
#   'flightled',
#   'hold'],
#  ['flight',
#   'today',
#   'rsw',
#   'grr',
#   'able',
#   'snag',
#   'free',
#   'sw',
#   'agent',
#   'check',
#   'look',
#   'like',
#   'finally',
#   'set'],
#  ['yes', 'say', 'take', 'hour'],
#  ['destinationdragon',
#   'tix',
#   'tonite',
#   'inconvenience',
#   'play',
#   'scavenger',
#   'hunt'],
#  ['great',
#   'job',
#   'today',
#   'team',
#   'challenging',
#   'weather',
#   'delay',
#   'flight',
#   'charlotte',
#   'travel',
#   'friendlyteam'],
#  ['hour', 'late', 'flightr', 'lose', 'conection', '😡'],
#  ['hour',
#   'delay',
#   'hour',
#   'increment',
#   'amp',
#   'mosaic',
#   'pay',
#   'use',
#   'lounge',
#   'waste',
#   'sunday'],
#  ['stick', 'phx', 'overnight', 'service', 'get', 'bad', 'fly', 'southwest'],
#  ['thank'],
#  ['luv',
#   'stop',
#   'overheat',
#   'plane',
#   'second',
#   'flight',
#   'row',
#   'feel',
#   'like',
#   'sauna'],
#  ['kind',
#   'gentleman',
#   'gate',
#   'tell',
#   'leave',
#   'hotel',
#   'voucher',
#   'ticket',
#   'gate',
#   'take'],
#  ['arrive', 'atlanta', 'wait', 'hour', 'luggage', 'place', 'carousel', 'hour'],
#  ['yesterday',
#   'delay',
#   'hour',
#   'w',
#   'lil',
#   'explanation',
#   'pay',
#   'lots',
#   'fly',
#   'w',
#   'u',
#   'amp',
#   'u',
#   'treat',
#   'ur',
#   'customer'],
#  ['mom',
#   'leave',
#   'kindle',
#   'flight',
#   'today',
#   'burgundy',
#   'case',
#   'light',
#   'seat',
#   'find'],
#  ['flight',
#   'love',
#   'field',
#   'sfo',
#   'definitely',
#   'cancel',
#   'flightled',
#   'monday',
#   'february'],
#  ['guy', 'work', 'fly', 'guy'],
#  ['thing', 'passbook', 'virgin', 'mobile', 'mexico', 'integrate'],
#  ['connect', 'flight'],
#  ['wife',
#   'try',
#   'group',
#   'client',
#   'destination',
#   'get',
#   'disconnected',
#   'hour',
#   'hold',
#   'help'],
#  ['dang', 'think', 'teleportation', 'device'],
#  ['friend', 'schedule', 'close', 'lax', 'reimburse', 'cost', 'hrs'],
#  ['let', 'reuse', 'ticket', 'book', 'vacation', 'delta', 'fly', 'american'],
#  ['lord', 'why“jetblue', 'fleet', 'fleek'],
#  ['cardholder', 'fly', 'airways', 'advantage', 'card', 'frustrating'],
#  ['hey',
#   'add',
#   'intl',
#   'number',
#   'error',
#   'check',
#   'go',
#   'hr',
#   'look',
#   'way',
#   'checkin',
#   'cancun'],
#  ['sit',
#   'charlotte',
#   'airport',
#   'hour',
#   'wait',
#   'crew',
#   'maintenance',
#   'neveragain'],
#  ['charge', 'flight', 'lol', 'time', 'fly'],
#  ['classy'],
#  ['refund', 'vacation', 'free', 'room', 'night', 'make', 'sleep', 'dia'],
#  ['ticket', 'atlanta', '😆'],
#  ['look',
#   'day',
#   'watch',
#   'deal',
#   'specific',
#   'date',
#   'fare',
#   'finder',
#   'help'],
#  ['scheduling',
#   'skill',
#   'fail',
#   'delay',
#   'go',
#   'hour',
#   'nearly',
#   'tell',
#   'snowbound',
#   'pbi'],
#  ['rebooke',
#   'sfo',
#   'arrive',
#   'hour',
#   'late',
#   'flight',
#   'miss',
#   'activity',
#   'ask',
#   'fly',
#   'today',
#   'stop',
#   'tell',
#   'pay'],
#  ['nice', 'lofty', 'view', 'silverstatus'],
#  ['bet', 'will', 'not', 'honour', 'like', 'ey'],
#  ['kind', 'cool', 'run', 'boss', 'man', 'sfo'],
#  ['tell', 'check', 'soon', 'allow', 'seat', 'available', 'plane', 'middle'],
#  ['sister',
#   'zero',
#   'food',
#   'cross',
#   'country',
#   'flight',
#   'type',
#   'warning',
#   'voucher'],
#  ['check', 'dm', 'pls'],
#  ['consider',
#   'continue',
#   'point',
#   'program',
#   'receive',
#   'perk',
#   'continue',
#   'bad',
#   'customer',
#   'service',
#   'senseless'],
#  ['jetblue', 'sofly', 'wish', 'firststari', 'seetonight'],
#  ['phone',
#   'call',
#   'hrs',
#   'send',
#   'amp',
#   'forth',
#   'line',
#   'terminal',
#   'skycap',
#   'find',
#   'solution'],
#  ['guy',
#   'luggage',
#   'san',
#   'jose',
#   'suppose',
#   'deliver',
#   'hotel',
#   'hour',
#   'ago',
#   'contact'],
#  ['great',
#   'decision',
#   'making',
#   'skill',
#   'flight',
#   'op',
#   'iah',
#   'bag',
#   'make',
#   'minute',
#   'connection',
#   'flight',
#   'push',
#   'early',
#   'disappoint'],
#  ['shout',
#   'flight',
#   'crew',
#   'take',
#   'amazing',
#   'care',
#   'double',
#   'flight',
#   'thankyou'],
#  ['call', 'different', 'office', 'sign', 'baggage', 'time', 'american', 'air'],
#  ['message', 'send', 'thank'],
#  ['damn', 'delay'],
#  ['worth', 'say', 'litter', 'singapore', 'cane', 'rule', 'say'],
#  ['go', 'sacramento', 'minneapolis', 'end', 'october', 'business', 'class'],
#  ['take',
#   'sit',
#   'schedule',
#   'buenos',
#   'are',
#   'jfk',
#   'sre',
#   'r',
#   'thy',
#   'holding',
#   'plane'],
#  ['dcagthpn',
#   'u',
#   'r',
#   'prof',
#   'hostage',
#   'taker',
#   'stand',
#   'bus',
#   'plane',
#   'min',
#   'sit',
#   'plane',
#   'mvmt',
#   'amp',
#   'announcement',
#   'gt',
#   'hour'],
#  ['liar',
#   'precipitation',
#   'day',
#   'degree',
#   'pacify',
#   'look',
#   'like',
#   'fool',
#   'that',
#   'problem',
#   'admit',
#   'suck'],
#  ['ugh', 'know', 'way', 'heart', '😘', '🙌'],
#  ['rcvd',
#   'promo',
#   'book',
#   'flight',
#   'silver',
#   'status',
#   'extend',
#   'not',
#   'flier',
#   'send',
#   'not',
#   'think',
#   'would',
#   'need'],
#  ['expect', 'wait', 'time', 'speak', 'number'],
#  ['poor',
#   'show',
#   'today',
#   'assistance',
#   'passenger',
#   'mi',
#   'connect',
#   'maintenance',
#   'wait',
#   'baggage'],
#  ['impression', 'hard', 'reverse', 'horrible', 'experience', 'fly'],
#  ['change'],
#  ['like',
#   'speak',
#   'vp',
#   'custexp',
#   'jimmy',
#   'samartzis',
#   'send',
#   'survey',
#   'email',
#   'awful',
#   'flight',
#   'exp'],
#  ['music', 'hold', 'hour', 'try', 'aadvantage', 'membership', 'merge', 'asap'],
#  ['thank', 'den', 'min', 'tarmac'],
#  ['mexico', 'international'],
#  ['sheer',
#   'incompetence',
#   'reign',
#   'dfw',
#   'today',
#   'plane',
#   'gd',
#   'runway',
#   'doubt'],
#  ['cancel',
#   'flight',
#   'flight',
#   'phl',
#   'delta',
#   'fly',
#   'flight',
#   'time',
#   'time',
#   'cancel',
#   'flighted',
#   'reason'],
#  ['help', 'check', 'expect', 'travel', 'painful', 'like', 'rest', 'sudden'],
#  ['horrible',
#   'experience',
#   'key',
#   'west',
#   'lose',
#   'luggage',
#   'call',
#   'check',
#   'amp',
#   'tell',
#   'reconsider',
#   'flight'],
#  ['fleet', 'fleek'],
#  ['hold',
#   'hour',
#   'get',
#   'connect',
#   'come',
#   'airport',
#   'rep',
#   'essentially',
#   'tell',
#   'screw'],
#  ['happily',
#   'wait',
#   'terminal',
#   'near',
#   'food',
#   'restroom',
#   'non',
#   'irritated',
#   'passenger'],
#  ['info',
#   'destinationdragons',
#   'winner',
#   'announce',
#   'amp',
#   'good',
#   'friend',
#   'hope',
#   'win',
#   'thank'],
#  ['nope', 'give', 'maybe', 'deliver'],
#  ['want',
#   'commit',
#   'say',
#   'plane',
#   'get',
#   'cancel',
#   'flighted',
#   'customer',
#   'relation',
#   'closed',
#   'patience',
#   'go'],
#  ['hear',
#   'blah',
#   'blah',
#   'blah',
#   'shoulda',
#   'buy',
#   'ticket',
#   'instead',
#   'amp',
#   'ill',
#   'drive',
#   'fly'],
#  ['thank', 'compensate', 'lose', 'bag', 'fly', 'unitedairlines'],
#  ['guy',
#   'start',
#   'flight',
#   'end',
#   'month',
#   'guess',
#   'road',
#   'trip',
#   'feb',
#   '…'],
#  ['option',
#   'cancelled',
#   'flight',
#   'want',
#   'change',
#   'flight',
#   'want',
#   'cancel',
#   'flight'],
#  ['miss',
#   'flight',
#   'connection',
#   'flight',
#   'attendant',
#   'delay',
#   'voucher',
#   'fail'],
#  ['plane', 'crew', 'professional', 'courteous', 'gate', 'agent', 'fluster'],
#  ['thank', 'goodness', 'friday', 'nwkgtsf', 'boom'],
#  ['bag', 'palm', 'springs', 'airport', 'lax', 'come', 'beat', 'bag'],
#  ['fly',
#   'flight',
#   'tomorrow',
#   'pbi',
#   'board',
#   'position',
#   'flight',
#   'overbooke',
#   'funeral',
#   'attend'],
#  ['problem', 'laptop', 'phone'],
#  ['check', 'standby', 'class', 'find', 'list', 'merger', 'pain'],
#  ['buy',
#   'safety',
#   'ticket',
#   'online',
#   'refund',
#   'whichever',
#   'tickets',
#   'unused',
#   'penalty'],
#  ['thank', 'u', '😘', 'course', 'safety', 'sure', 'handle', 'care', 'love'],
#  ['thank', 'idea', 'resolve', 'like', 'purchase', 'ticket'],
#  ['customer', 'rep', 'help', 'option', 'get'],
#  ['thank',
#   'explanation',
#   'like',
#   'odd',
#   'incentive',
#   'structure',
#   'tho',
#   'dramatically',
#   'diminish',
#   'value',
#   'cert'],
#  ['try', 'email', 'talk', 'business', 'people', 'expect', 'airline', 'wifi'],
#  ['male',
#   'flight',
#   'attendant',
#   'flight',
#   'orlando',
#   'indy',
#   'amazing',
#   'need',
#   'raise',
#   '👍',
#   'good',
#   'experience'],
#  ['hopefully',
#   'crappy',
#   'service',
#   'improve',
#   'u',
#   'angryairtravel',
#   'winterstorm'],
#  ['physically',
#   'impossible',
#   'airport',
#   'flight',
#   'schedule',
#   'leave',
#   'hour'],
#  ['thank'],
#  ['check', 'probably', 'hand', 'oscar', 'nerd', 'geek', 'badly', 'dress'],
#  ['look', 'beauty', '😉', 'dc', 'united', 'airlines', '😉'],
#  ['flight', 'delay', 'pilot', 'board', 'sit', 'scheduling'],
#  ['finally', 'get', 'home', 'bnasnow'],
#  ['bump',
#   'flight',
#   'hrl',
#   'minute',
#   'early',
#   'staff',
#   'rude',
#   'ask',
#   'problem'],
#  ['hey',
#   'fly',
#   'tampa',
#   'denver',
#   'today',
#   'want',
#   'know',
#   'tv',
#   'seat',
#   'like'],
#  ['msg',
#   'customer',
#   'service',
#   'invoice',
#   'dry',
#   'cleaning',
#   'will',
#   'able',
#   'wet',
#   'clothe',
#   'airport'],
#  ['best', 'pleased', 'service', 'far', 'gate', 'guarantee', 'correct'],
#  ['okay', 'thank', 'hope', 'fly', 'guy', 'soon'],
#  ['read', 'case', 'define', 'example', 'case'],
#  ['handle', 'phone', 'unfortunately', 'wipe', 'entire', 'trip', 'displeased'],
#  ['thank', '😃'],
#  ['people',
#   'wait',
#   'line',
#   'customer',
#   'service',
#   'den',
#   'deal',
#   'flight',
#   'cancel',
#   'flightation'],
#  ['have',
#   'trouble',
#   'flight',
#   'booking',
#   'problems',
#   'seat',
#   'march',
#   'operate',
#   'aa',
#   'airline',
#   'website',
#   'allow',
#   'seat',
#   'selection'],
#  ['entire',
#   'flight',
#   'crew',
#   'flight',
#   'bos',
#   'phl',
#   'wonderful',
#   'job',
#   'make',
#   'experience',
#   'totally',
#   'suck',
#   '😊'],
#  ['want',
#   'love',
#   'minute',
#   'hold',
#   'help',
#   'understand',
#   'switch',
#   'loyalty',
#   'program'],
#  ['thank',
#   'concerned',
#   'conflict',
#   'text',
#   'receive',
#   'flight',
#   'have',
#   'drive',
#   'hour',
#   '😢'],
#  ['need', 'song', 'commercial', 'swa', 'love'],
#  ['board', 'tomorrow'],
#  ['fun',
#   'screw',
#   'early',
#   'flight',
#   'crummyservice',
#   'whydidntiflysouthw',
#   'goodluckamericanair'],
#  ['processing',
#   'error',
#   'send',
#   'flight',
#   'ticket',
#   'confirmation',
#   'flysouthwest'],
#  ['possibly',
#   'mess',
#   'trip',
#   'anymore',
#   'thank',
#   'terrible',
#   'airline',
#   'disappoint'],
#  ['official', 'airline', 'divadapouch', 'aka', 'thepoopqueen'],
#  ['passenger',
#   'wait',
#   'inside',
#   'flight',
#   'runway',
#   'return',
#   'o',
#   'gate',
#   'count',
#   'valid',
#   'journey'],
#  ['stop', 'cut', 'paste', 'apology', 'additional', 'phone', 'rep', 'job'],
#  ['team', 'offer', 'inflight', 'access', 'journal', 'broadway', 'world'],
#  ['delay',
#   'departure',
#   'hrs',
#   'wait',
#   'passenger',
#   'flight',
#   'late',
#   'flight',
#   'unacceptable'],
#  ['min', 'hold', 'progress', 'hour'],
#  ['news', 'gate', 'option'],
#  ['figure',
#   'flight',
#   'hard',
#   'believe',
#   'oil',
#   'low',
#   'killing',
#   'u',
#   'hotel',
#   'compd'],
#  ['ta', 'site', 'thelodge', 'fun', 'day'],
#  ['love', 'fly', 'good', 'friend', 'home', 'pvd', 'weekend', '😊'],
#  ['sure', 'question', 'remain', 'find', 'crew', 'will', 'come', 'flt', 'tks'],
#  ['printer', 'problem', 'cause', 'sit', 'runway', 'min'],
#  ['call', 'number', 'left', 'message', 'pass', 'message', 'team'],
#  ['aa',
#   'frequent',
#   'flyer',
#   'number',
#   'appear',
#   'usair',
#   'reservation',
#   'frustrating'],
#  ['good', 'home', 'texas', 'moodlighte'],
#  ['flight', 'rude', 'rude', 'rude', 'service', 'awful'],
#  ['look',
#   'beauty',
#   '😉',
#   'united',
#   'airlines',
#   '😉',
#   'hope',
#   'like',
#   'beauty',
#   '😉'],
#  ['fly', 'figure', 'worth', 'mile', 'lifetime', 'flight', 'airways'],
#  ['lose',
#   'luggage',
#   'infant',
#   'year',
#   'old',
#   'customer',
#   'service',
#   'answer',
#   'phone',
#   'try',
#   'night'],
#  ['wonderful',
#   'flight',
#   'attendant',
#   'name',
#   'leah',
#   'lga',
#   'den',
#   'den',
#   'anchorage'],
#  ['stick',
#   'miami',
#   'bad',
#   'customer',
#   'experience',
#   'sure',
#   'let',
#   'know',
#   'time',
#   'w',
#   'aa'],
#  ['penalize', 'pack', 'lightly', 'have', 'bag', 'pay', 'extra', 'seat'],
#  ['direct', 'tv', 'work', 'avoid', 'future'],
#  ['page', 'cancel', 'flighted', 'min', 'ago', 'help', 'flight', 'mco'],
#  ['excited',
#   'time',
#   'sunday',
#   'march',
#   'fly',
#   'jetblue',
#   'flight',
#   'mint',
#   'jfk',
#   'look',
#   'forward'],
#  ['consolation', 'staff', 'stellar', 'hour', 'delay', 'encounter', 'flight'],
#  ['cancel',
#   'flighted',
#   'flight',
#   'leave',
#   'help',
#   'find',
#   'hotel',
#   'stay',
#   'sleep',
#   'airport',
#   'night'],
#  ['chance', 'seat', 'open', 'den', 'dal', 'afternoon'],
#  ['flight',
#   'work',
#   'screen',
#   'friend',
#   'possible',
#   'place',
#   'unitedfailsworsttripofmylife'],
#  ['try', 'week', 'use'],
#  ['international'],
#  ['wow', 'guy', 'answer', 'people', 'wow', 'care', 'love', 'jet', 'blue'],
#  ['appreciate',
#   'fly',
#   'january',
#   'check',
#   'engine',
#   'light',
#   'come',
#   'right',
#   'computer'],
#  ['connecticut', '❄', '️'],
#  ['preciate',
#   'not',
#   'plane',
#   'speak',
#   'w',
#   'agent',
#   'will',
#   'not',
#   'come',
#   'plane',
#   'knoxville'],
#  ['cancel',
#   'flighted',
#   'flight',
#   'leave',
#   'help',
#   'find',
#   'hotel',
#   'stay',
#   'sleep',
#   'airport',
#   'night'],
#  ['get', 'lose', 'kindle', 'mail', 'thank'],
#  ['fly', 'toronto', 'kill', 'small'],
#  ['service',
#   'awful',
#   'boston',
#   'pay',
#   'extra',
#   'dollar',
#   'suppose',
#   'dissatisfied',
#   'mad'],
#  ['read', 'day', 'travel', 'change', 'policy'],
#  ['vacation',
#   'budget',
#   'blow',
#   'bc',
#   'lack',
#   'communication',
#   'usairway',
#   'use',
#   'refer'],
#  ['date', 'destination', 'head', '😔'],
#  ['consider', 'purchase', 'attempt', 'use', 'believe', 'fit', 'parameter'],
#  ['julie', 'andrews', 'way', 'impressive'],
#  ['home', 'use', 'company', 'available', 'unfair', 'stay', 'h', 'travel'],
#  ['thank'],
#  [],
#  ['announce', 'roller', 'want', 'coat', 'choice', 'gate', 'check', 'thx'],
#  ['flight',
#   'booking',
#   'problems',
#   'section',
#   'website',
#   'break',
#   'chrome',
#   'wanna',
#   'look'],
#  ['understand',
#   'weather',
#   'fault',
#   'frequent',
#   'flyer',
#   'expect',
#   'well',
#   'customer',
#   'service',
#   'try'],
#  ['delay',
#   'tpa',
#   'bdl',
#   'better',
#   'safe',
#   'sorry',
#   '💙',
#   'lovejetblue',
#   'onlyblue',
#   'jetblueforever'],
#  ['frustrated',
#   'conversation',
#   'united',
#   'speak',
#   'spanish',
#   'courier',
#   'company',
#   'bag'],
#  ['receive', 'response', 'direct', 'message', 'contact', 'information'],
#  ['wait', 'time', 'customer', 'service', 'line', 'try', 'fri', 'min'],
#  ['sure',
#   'upgrade',
#   'list',
#   'ewr',
#   'pdx',
#   'gpu',
#   'priority',
#   'got',
#   'weird',
#   'email'],
#  ['phone'],
#  ['update', 'flightit', 'hour', 'delay', 'thank'],
#  ['need', 'hold', 'hang', 'phone', 'system', 'hour'],
#  ['try',
#   'cancel',
#   'flight',
#   'fligt',
#   'ohare',
#   'dallas',
#   'high',
#   'volume',
#   'answer',
#   'online',
#   'confirmation',
#   'thanku'],
#  ['stop'],
#  ['get', 'got', 'excuses', 'usairwaysfail'],
#  ['sad',
#   'experience',
#   'today',
#   'family',
#   'southwest',
#   'direct',
#   'mco',
#   'loyalty',
#   'usair',
#   'vacation',
#   'boy',
#   'today'],
#  ['customer',
#   'service',
#   'terrible',
#   'wait',
#   'week',
#   'reply',
#   'email',
#   'helpful',
#   'brush',
#   'problem'],
#  ['one', 'difficult'],
#  ['wife',
#   'fly',
#   'italy',
#   'recently',
#   'buy',
#   'ticket',
#   'finnair',
#   'flight',
#   'operate',
#   'usair',
#   'dividend',
#   'mile',
#   'credit'],
#  ['sure', 'dmed'],
#  ['seriously', 'rep', 'available', 'phone', 'call', 'platinum'],
#  ['voucher', 'pick', 'bag'],
#  ['good', 'luck', 'wait', 'week'],
#  ['rebooked',
#   'arrive',
#   'hour',
#   'late',
#   'flightr',
#   'year',
#   'hrs',
#   'san',
#   'diego',
#   'inflight',
#   'entertainment'],
#  ['thank', 'speedy', 'flight', 'time', 'recovery'],
#  ['aa'],
#  ['thank', 'occur', 'guy', 'hour', 'extra', 'bag', 'delay', 'hour', 'fail'],
#  ['thank', 'update'],
#  ['complete',
#   'waste',
#   'day',
#   'trip',
#   'work',
#   'turn',
#   'sit',
#   'plane',
#   'day',
#   'ridiculous'],
#  ['weather',
#   'keep',
#   'slow',
#   'fault',
#   'time',
#   'southwest',
#   'flight',
#   'late',
#   'flight',
#   'complain'],
#  ['luggage', 'forgot', 'win', 'oscar', '😄', '💝', '💝', '💝'],
#  ['nyc', 'flight', 'delay', 'miss', 'connection', 'sacramento', 'chicago'],
#  ['look', 'forward', 'jb', 'rt', 'look', 'forward', 'welcome', 'onboard', '💙'],
#  ['suck',
#   'delay',
#   'mom',
#   'flight',
#   'cancelled',
#   'flightle',
#   'delay',
#   'flight',
#   'today',
#   'mech',
#   'issue',
#   'sleep',
#   'airport'],
#  ['oh', 'issue', 'resolve', 'air'],
#  ['unitedairlines', 'long', 'delay'],
#  ['flight',
#   'cancel',
#   'flightled',
#   'call',
#   'say',
#   'hang',
#   'say',
#   'wait',
#   'hrs'],
#  ['come', 'catch', 'home', 'dca', 'let', 'great', 'leg', 'tonight'],
#  ['flight', 'vieque', 'good', 'right', 'look', 'promise'],
#  ['update', 'dot', 'look', 'united', 'fare', 'london', 'week'],
#  ['need', 'customer', 'service', 'manager', 'contact'],
#  ['thank', 'beareavement', 'discount', 'anymore', 'book', 'online'],
#  ['hey', 'sexy', 'tattoo', 'get', 'left', 'engine', 'jetbae'],
#  ['cmh',
#   'gate',
#   'staff',
#   'disaster',
#   'overbooke',
#   'volunteer',
#   'boarding',
#   'min',
#   'late',
#   'flight',
#   'try',
#   'figure',
#   'issue',
#   'bringbackrealstaff'],
#  ['run',
#   'money',
#   'pay',
#   'hotel',
#   'room',
#   'amp',
#   'food',
#   'nyc',
#   'help',
#   'people',
#   'spend'],
#  ['get',
#   'email',
#   'update',
#   'eta',
#   'communication',
#   'detail',
#   'apology',
#   'info',
#   'compensation',
#   'right',
#   'long',
#   'way'],
#  ['contact', 'awful', 'experience', 'flight', 'buf', 'clt'],
#  ['thank', 'feel', 'like', 'system', 'fail', 'solution'],
#  ['good', 'morning', 'let', 'know', 'able', 'luggage', 'tag', 'tx'],
#  ['call', 'baggage', 'status', 'time', 'yesterday'],
#  ['send',
#   'gate',
#   'agent',
#   'talk',
#   'joke',
#   'airline',
#   'thank',
#   'ruin',
#   'vacation',
#   'neverflyaaagain'],
#  ['send', 'feedback', 'rep', 'tell', 'priority', 'speechless', 'system'],
#  ['worried',
#   'bag',
#   'go',
#   'san',
#   'dca',
#   'hour',
#   'reunion',
#   'organized',
#   'breeze'],
#  ['cancel',
#   'flight',
#   'flight',
#   'versace',
#   'bicep',
#   'stow',
#   'completely',
#   'seat'],
#  ['delta', 'reroute', 'bag', 'mia', 'cur', 'flight'],
#  ['drunk',
#   'guy',
#   'throw',
#   'flight',
#   'ago',
#   'well',
#   'rest',
#   'hold',
#   'plane',
#   'food'],
#  ['fly', 'right', 'minute'],
#  ['airline', 'know', 'job'],
#  ['disappoint',
#   'flight',
#   'cancel',
#   'flighted',
#   'excited',
#   'listen',
#   'song',
#   'blue',
#   'fly',
#   'jetblue'],
#  ['travel', 'advisory', 'come', 'carolinas', 'bad', 'weather'],
#  ['lipstick',
#   'pig',
#   'pig',
#   'ur',
#   'new',
#   'baggage',
#   'claim',
#   'sju',
#   'disaster',
#   'chair',
#   'mins',
#   'wait',
#   'baggage',
#   'fail'],
#  ['want', 'speak', 'human', 'obscene', 'request'],
#  ['call',
#   'sick',
#   'forgot',
#   'replacement',
#   'hour',
#   'late',
#   'flight',
#   'theworst'],
#  ['get', 'let', 'log', 'email', 'thx', 'hope', 'dtw', 'ase', 'issue', 'today'],
#  ['equip', 'flamethrower', 'snow', 'plow'],
#  ['go', 'hour', 'okay', 'usair', 'okay', 'ruin'],
#  ['team', 'need', 'build', 'capacity'],
#  ['need', 'order', 'special', 'meal', 'reach', 'aa', 'hold', 'hour'],
#  ['call',
#   'resolve',
#   'dividend',
#   'mile',
#   'issue',
#   'week',
#   'avail',
#   'advise',
#   'asap'],
#  ['let', 'know', 'find', 'luggage', 'thank', 'unitedairlines'],
#  ['suppose',
#   'flight',
#   'charlotte',
#   'rdu',
#   'yesterday',
#   'flight',
#   'schedule',
#   'departure',
#   'tonight'],
#  ['mark', 't', 'austin', 'great', 'handle', 'bag', 'issue', 'thank'],
#  ['try', 'change', 'reservation', 'hang'],
#  ['disappointed',
#   'toll',
#   'free',
#   'number',
#   'terrible',
#   'customer',
#   'service',
#   'flight',
#   'cancel',
#   'flightled',
#   'like',
#   'home'],
#  ['million',
#   'mile',
#   'w',
#   'u',
#   'loyal',
#   'u',
#   'r',
#   'u',
#   'go',
#   'reciprocate',
#   'joke'],
#  ['think', 'guy', 'mess', 'thing', 'fly'],
#  ['comedian', 'promise', 'fun', 'stage', 'tonight'],
#  ['offer', 'sweep', 'link', 'go', 'work', 'b'],
#  ['fly', 'huntsville', 'al', 'nashville', 'birmingham'],
#  ['hold', 'hours', 'get', 'hang', 'oh', 'god'],
#  ['port',
#   'au',
#   'prince',
#   'haiti',
#   'continued',
#   'food',
#   'distribution',
#   'medical',
#   'supply',
#   'amp',
#   'orphan',
#   'care',
#   'flyingitforward',
#   'k'],
#  ['hear', 'wrong', 'sweet', 'mixtape', 'record', 'leave', 'leave'],
#  ['despite',
#   'mechanical',
#   'issue',
#   'delay',
#   'follow',
#   'cancelled',
#   'flightlation',
#   'get',
#   'vegas',
#   'thank',
#   'great',
#   'gate',
#   'agent'],
#  ['flight',
#   'far',
#   'year',
#   'delay',
#   'include',
#   'cancel',
#   'flightation',
#   'late',
#   'flightst',
#   'reason',
#   'crew',
#   'need',
#   'mandatory',
#   'sleep',
#   'mexico'],
#  ['oh',
#   'yay',
#   'gate',
#   'agent',
#   'decide',
#   'deal',
#   'upgrade',
#   'list',
#   'bump',
#   'close'],
#  ['appreciate',
#   'response',
#   'pressurization',
#   'failure',
#   'flight',
#   'respond',
#   'issue'],
#  ['got',
#   'drink',
#   'f',
#   'sit',
#   'jump',
#   'seat',
#   'crossword',
#   'glass',
#   'pick',
#   'landing',
#   'lazy',
#   'service',
#   'class'],
#  ['cover',
#   'rental',
#   'car',
#   'refund',
#   'ticket',
#   'gladly',
#   'drive',
#   'hrs',
#   'home',
#   'stick',
#   'till',
#   'tue'],
#  ['check',
#   'security',
#   'wrong',
#   'give',
#   'wrong',
#   'boarding',
#   'pass',
#   'airlinesecurity'],
#  ['important',
#   'morning',
#   'seat',
#   'wife',
#   'allow',
#   'choose',
#   'seat',
#   'flight',
#   'booking',
#   'problems'],
#  ['disappoint',
#   'service',
#   'start',
#   'gate',
#   'operator',
#   'bos',
#   'rude',
#   'stop',
#   'carry',
#   'bag'],
#  ['nope', 'case', 'would', 'time'],
#  ['wait',
#   'hour',
#   'finally',
#   'board',
#   'airplane',
#   'find',
#   'maintenance',
#   'plane',
#   'cold',
#   '😡'],
#  ['little', 'help', 'husband', 'hold', 'hour', 'minute', 'complete'],
#  ['appreciate',
#   'get',
#   'hold',
#   'get',
#   'hang',
#   'request',
#   'help',
#   'big',
#   'group',
#   'try',
#   'delta'],
#  ['hit',
#   'typical',
#   'wait',
#   'time',
#   'right',
#   'drive',
#   'm',
#   'airport',
#   'service',
#   'desk'],
#  ['look', 'forward', 'fly', 'guy'],
#  ['check', 'yesterday', 'look', 'like', 'change'],
#  ['hope', 'pray', 'safe', 'flight', 'stop', 'de', 'ice', 'plane', '😞'],
#  ['wait', 'hour', 'talk', 'change', 'flight'],
#  ['course', 'work', 'obsess', 'entire', 'virgin', 'family'],
#  ['delay',
#   'salt',
#   'floor',
#   'previous',
#   'passenger',
#   'want',
#   'fly',
#   'care',
#   'shoe'],
#  ['ticket',
#   'office',
#   'boston',
#   'impossible',
#   'book',
#   'phone',
#   'use',
#   'voucher',
#   'website',
#   'headache',
#   'help'],
#  ['instal', 'working', 'kick', 'hour', 'let', 'waste', 'hour'],
#  ['great', 'job', 'celebrate', 'industry', 'reason', 'nuts'],
#  ['crew', 'help'],
#  ['time', 'try', 'tell', 'try', 'late', 'flightr', 'hang'],
#  ['love',
#   'service',
#   'staff',
#   'newark',
#   'today',
#   'good',
#   'service',
#   'go',
#   'way',
#   'appreciate',
#   'preciation',
#   'nj',
#   '✈',
#   '️tampa',
#   '🔵',
#   '🔵',
#   '🔵'],
#  ['lekvhg', 'want', 'cost', 'change', 'flight'],
#  ['close'],
#  ['fleet', 'fleek', 'wow'],
#  ['feel', 'guilty', 'economy', 'plus', 'pay', 'extra', 'leg', 'room'],
#  ['hour',
#   'late',
#   'flightr',
#   'site',
#   'plane',
#   'wait',
#   'leave',
#   'think',
#   'credit',
#   'order',
#   'terrible',
#   'service'],
#  ['bad',
#   'coffee',
#   'juice',
#   'ok',
#   'getphilz',
#   'united',
#   'terminal',
#   'sfo',
#   'airport'],
#  ['flight',
#   'cancel',
#   'flightled',
#   'monday',
#   'look',
#   'cancel',
#   'flight',
#   'credit',
#   'card'],
#  ['better', 'have', 'hold', 'hr'],
#  ['😂',
#   '😂',
#   '😂',
#   '😂',
#   '😂',
#   'omg',
#   'bored',
#   'amp',
#   'read',
#   'convo',
#   'like',
#   'jetblue',
#   'point'],
# ...
#   'confirmation'],
#  ['jetblue', 'officially', 'lose', 'customer', 'waste', 'point', 'flight'],
#  ['staff', 'try', 'throw', 'luggage'],
#  ['finally',
#   'board',
#   'door',
#   'close',
#   'reopen',
#   'need',
#   'fuel',
#   'think',
#   'wd',
#   'think',
#   'earlier'],
#  ['fucking', 'suck'],
#  ['false'],
#  ['like', 'hear', 'help', 'thank', 'offer', 'help'],
#  ['chairman', 'phone', 'number', 'use'],
#  ['record',
#   'loaaret',
#   'get',
#   'email',
#   'reschedule',
#   'flight',
#   'know',
#   'flight',
#   'cancel',
#   'flightled'],
#  ['think',
#   'safe',
#   'year',
#   'loyal',
#   'jetblue',
#   'fly',
#   'officially',
#   'byebyejetblue'],
#  ['want'],
#  ['maintenance',
#   'flight',
#   'land',
#   'jamaica',
#   'security',
#   'term',
#   'clean',
#   'board'],
#  ['jan', 'summer'],
#  ['lmfao'],
#  ['good',
#   'u',
#   'refund',
#   'billing',
#   'cycle',
#   'month',
#   'u',
#   'guy',
#   'ask',
#   'chance'],
#  ['wow', 'awful', 'customer', 'service'],
#  ['need',
#   'help',
#   'record',
#   'locator',
#   'bring',
#   'different',
#   'flight',
#   'system',
#   'op',
#   'aa',
#   'amp',
#   'airways'],
#  ['ability', 'ticket', 'counter', 'cust', 'service', 'online'],
#  ['midland',
#   'bag',
#   'connect',
#   'intl',
#   'flight',
#   'sydney',
#   'la',
#   'amp',
#   'check'],
#  ['sit', 'plane', 'hrs', 'finally', 'take'],
#  ['strand',
#   'customer',
#   'reflight',
#   'book',
#   'problem',
#   'answer',
#   'phone',
#   'way',
#   'treat',
#   'platinum',
#   'member'],
#  ['yes', 'party', '😂'],
#  ['happen',
#   'plane',
#   'mean',
#   'leave',
#   'wait',
#   'buffalo',
#   'organizational',
#   'error',
#   'weather'],
#  ['mother',
#   'flight',
#   'delay',
#   'phl',
#   'ord',
#   'way',
#   'nrt',
#   'gate',
#   'refuse',
#   'upgrade',
#   'platinum',
#   'blegh'],
#  ['need',
#   'report',
#   'complete',
#   'disregard',
#   'pay',
#   'customer',
#   'donotflywiththem'],
#  ['guy',
#   'know',
#   'musician',
#   'sensitive',
#   'safety',
#   'instrument',
#   'fly',
#   'good',
#   'reason'],
#  ['send'],
#  ['new',
#   'plane',
#   'gogo',
#   'easy',
#   'power',
#   'laptop',
#   'iphone',
#   'miss',
#   'good',
#   'boat',
#   'style',
#   'swivel',
#   'cup',
#   'holder',
#   'dietcoke',
#   'happyfli'],
#  ['imagine',
#   'hard',
#   'spend',
#   'money',
#   'air',
#   'stubbornly',
#   'hope',
#   'come',
#   'phone'],
#  ['website',
#   'will',
#   'let',
#   'change',
#   'online',
#   'airline',
#   'issue',
#   'travel',
#   'advisory',
#   'hold',
#   'minute',
#   'help'],
#  ['fly',
#   'w',
#   'u',
#   'kiosk',
#   'break',
#   'syr',
#   'woman',
#   'work',
#   'ticket',
#   'counter'],
#  ['feel', 'informed', 'yes', 'flight', 'delay', 'thank'],
#  ['cancel',
#   'flightling',
#   'flight',
#   'send',
#   'ticket',
#   'tell',
#   'buyer',
#   'jetblue',
#   'allow'],
#  ['wait',
#   'bag',
#   'get',
#   'deliver',
#   'yesterday',
#   'reach',
#   'real',
#   'person',
#   'help',
#   'send',
#   'dm',
#   'ref',
#   'number'],
#  ['shout',
#   'pilot',
#   'fc',
#   'attendanteliz',
#   'super',
#   'strong',
#   'crosswind',
#   'landing',
#   'eliz',
#   'super',
#   'job'],
#  ['long', 'customer', 'feedback', 'respond', 'complaint'],
#  ['come', 'home', 'day', 'late', 'flight', 'find', 'guy', 'lose', 'luggage'],
#  ['u', 'safety', 'high', 'priority', 'extend', 'property', 'totally', 'nuts'],
#  ['start', 'robotic', 'response'],
#  ['speak', 'soon', 'bag', 'lose'],
#  ['hand',
#   'slip',
#   'paperampsaid',
#   'call',
#   'day',
#   'try',
#   'send',
#   'layover',
#   'airport',
#   'ref',
#   'tho'],
#  ['stick',
#   'florida',
#   'flight',
#   'service',
#   'suck',
#   'nofood',
#   'nodrink',
#   'nohelp'],
#  ['friend', 'picture', 'phillip', 'heller', 'jfk', 'ifc', 'say', 'delicious'],
#  ['beats',
#   'eps',
#   'views',
#   'take',
#   'southwestair',
#   'va',
#   'luv',
#   'investor',
#   'business',
#   'daily'],
#  ['amazing', 'view', 'approach', 'lax', 'tonight'],
#  ['flight',
#   'seattle',
#   'fuel',
#   'water',
#   'lavoratorie',
#   'nice',
#   'job',
#   'guy',
#   'est'],
#  ['luggage',
#   'set',
#   'dca',
#   'reroute',
#   'dulles',
#   'currently',
#   'nolo',
#   'bag',
#   'houston',
#   'fix'],
#  ['actually', 'consider', 'mistake', 'complain', 'indicate', 'reservation'],
#  ['list',
#   'prefer',
#   'den',
#   'dal',
#   'flight',
#   'cancel',
#   'flightled',
#   'min',
#   'prior',
#   'boarding',
#   'good',
#   'option',
#   'tue',
#   'afternoon',
#   'seriously',
#   'epic',
#   'fail'],
#  ['small', 'thing', 'detail', 'excellent', 'experience', 'irritate'],
#  ['kid', 'want', 'fucking', 'money', 'scumbag'],
#  ['certainly'],
#  ['thank', 'flight', 'today', 'great', 'crew'],
#  ['customer',
#   'svc',
#   'bad',
#   'winterweather',
#   'flight',
#   'cancel',
#   'flighted',
#   'website',
#   'malfunction',
#   'hold'],
#  ['work', 'tell', 'fault', 'late', 'flight'],
#  ['efficient',
#   'layout',
#   'kiosks',
#   'bag',
#   'drop',
#   'line',
#   'help',
#   'definition',
#   'space',
#   'additional',
#   'friendly',
#   'helpful',
#   'staff'],
#  ['week', 'pass', 'hope', 'response'],
#  ['sgf', 'dfw', 'want', 'clear', 'ice', 'plane', 'landing', '😳'],
#  ['delay',
#   'way',
#   'puerto',
#   'rico',
#   'delay',
#   'way',
#   'new',
#   'york',
#   'disgraceful'],
#  ['feel',
#   'like',
#   'good',
#   'day',
#   'fly',
#   'thank',
#   'ontime',
#   'departure',
#   'sna',
#   'bestinclass',
#   'ft',
#   'takemehome'],
#  ['reserve', 'seat', 'aa', 'flight', 'transfer', 'ord', 'evv'],
#  ['cancel',
#   'flightled',
#   'passenger',
#   'notify',
#   'complete',
#   'violation',
#   'traveler',
#   'right'],
#  ['power',
#   'outlet',
#   'seat',
#   'hour',
#   'flight',
#   'california',
#   'seriously',
#   'airline',
#   'fail',
#   'pathetic'],
#  ['hour',
#   'wait',
#   'phone',
#   'air',
#   'help',
#   'hour',
#   'wait',
#   'airport',
#   'yesterday',
#   'love',
#   'service',
#   'guy'],
#  ['awe', 'guy', 'great', 'wait', 'travel', 'soon'],
#  ['haha',
#   'right',
#   'change',
#   'thing',
#   'slash',
#   'twitter',
#   'engagement',
#   'make',
#   'cool',
#   'bestairline'],
#  ['dm', 'question'],
#  ['understand',
#   'plane',
#   'available',
#   'day',
#   'till',
#   'departure',
#   'unacceptable',
#   'phoenix'],
#  ['send',
#   'message',
#   'facebook',
#   'follow',
#   'complaint',
#   'miss',
#   'clothing',
#   'check',
#   'baggage'],
#  ['vomit', 'halfway'],
#  ['hey', 'let', 'know', 'bad', 'fucking', 'service', 'thank'],
#  ['yes', 'true', 'bit', 'pricey', 'look', 'love', 'guy'],
#  ['change',
#   'gate',
#   'tell',
#   'fuck',
#   'wrong',
#   'people',
#   'learn',
#   'fucken',
#   'job'],
#  ['nice',
#   'rt',
#   'vibe',
#   'moodlight',
#   'takeoff',
#   'touchdown',
#   'moodlitmonday',
#   'sciencebehindtheexperience'],
#  ['sincerely',
#   'thank',
#   'pilot',
#   'flight',
#   'brave',
#   'snow',
#   'get',
#   'home',
#   'cancel',
#   'flightlations'],
#  ['thing',
#   'know',
#   'united',
#   'believe',
#   'dot',
#   'court',
#   'united',
#   'anti',
#   'consumer'],
#  ['try', 'check', 'flight', 'line', 'work', 'amp', 'agent', 'busy'],
#  ['realize', 'clothe', 'hotel', 'suggestion'],
#  ['new',
#   'seat',
#   'assignment',
#   'service',
#   'embarrassment',
#   'airline',
#   'customer',
#   'worldwide',
#   'shameonyou',
#   'usairwayssuck'],
#  ['new', 'bad', 'take', 'americanairline', 'nocustomerservice', 'fail'],
#  ['delaney',
#   'shawn',
#   'dfw',
#   'show',
#   'exceptional',
#   'customer',
#   'service',
#   'today',
#   'happily',
#   'choose',
#   'aa',
#   'possible',
#   'thank'],
#  ['thank', 'give', 'away', 'seat', 'fine', 'job'],
#  ['good',
#   'gagent',
#   'long',
#   'time',
#   'danny',
#   'b',
#   'dfw',
#   'clt',
#   'appreciate',
#   'date',
#   'keep',
#   'irrop',
#   'super',
#   'professional'],
#  ['thank', 'appreciated', 'plane', 'min', 'gate'],
#  ['time', 'reevaluate', 'nyc', 'carrier'],
#  ['info',
#   'cancel',
#   'flightled',
#   'flight',
#   'tomorrow',
#   'morning',
#   'dfw',
#   'call',
#   'speak'],
#  ['flight',
#   'passenger',
#   'stick',
#   'plane',
#   'philly',
#   'gangway',
#   'hear',
#   'pilot'],
#  ['unfriendly',
#   'unhelpful',
#   'agent',
#   'unannounced',
#   'gate',
#   'change',
#   'delay',
#   'flight',
#   'find',
#   'word',
#   'mouth'],
#  ['clueless',
#   'aa',
#   'wait',
#   'hear',
#   'week',
#   'refund',
#   'cancel',
#   'flightled',
#   'flight',
#   'amp',
#   'hold'],
#  ['weather',
#   'excuse',
#   'poor',
#   'customer',
#   'service',
#   'lack',
#   'info',
#   'staff',
#   'fact',
#   'staff',
#   'turn'],
#  ['bag',
#   'mexico',
#   'build',
#   'house',
#   'amp',
#   'suitcase',
#   'get',
#   'flight',
#   'cle',
#   'w',
#   'need',
#   'm'],
#  ['man',
#   'sit',
#   'terminal',
#   'scent',
#   'tht',
#   'not',
#   'finger',
#   'pls',
#   'dnt',
#   'let',
#   'sit',
#   'flight'],
#  ['fact', 'chrishasmadeusblush', 'trend', 'know', 'loyal'],
#  ['yes'],
#  ['epicfail',
#   'cx',
#   'flight',
#   'frankfurt',
#   'san',
#   'francisco',
#   'go',
#   'chicago',
#   'flight',
#   'crew',
#   'hour',
#   'de',
#   'icing',
#   'delay'],
#  ['fampking',
#   'joke',
#   'customer',
#   'service',
#   'woeful',
#   'staff',
#   'tell',
#   'passenger'],
#  ['get',
#   'to',
#   'new',
#   'record',
#   'hrs',
#   'air',
#   'hrs',
#   'wait',
#   'bag',
#   'deliver',
#   'destination'],
#  ['wow'],
#  ['gabriela',
#   'miami',
#   'rude',
#   'employee',
#   'work',
#   'mia',
#   'lga',
#   'check',
#   'experience',
#   'unpleasant',
#   'customerexperience'],
#  ['cancel',
#   'flighted',
#   'flight',
#   'rebook',
#   'add',
#   'flight',
#   'drive',
#   'denver',
#   'kc',
#   'thank'],
#  ['mechanical', 'failure', 'boston', 'fault'],
#  ['absolutely', 'staff', 'amazing'],
#  ['lady',
#   'phone',
#   'say',
#   'tel',
#   'aviv',
#   'tel',
#   'aviv',
#   'united',
#   'say',
#   'newark',
#   'know'],
#  ['sincere', 'cancel', 'flighted', 'flight', 'drive', 'hour', 'home'],
#  ['apply', 'job', 'pdw', 'follow', 'love', 'job', 'ilovejetblue'],
#  ['hour',
#   'delay',
#   'plane',
#   'visible',
#   'airport',
#   'far',
#   'terrible',
#   'customer',
#   'service',
#   'neveragain'],
#  ['number', 'let', 'wait', 'customer', 'rep', 'frustrating', 'talk', 'human'],
#  ['go',
#   'compensate',
#   'day',
#   'plan',
#   'ruin',
#   'delay',
#   'pende',
#   'cancel',
#   'flightlation'],
#  ['oh',
#   'rebooke',
#   'hour',
#   'original',
#   'arrival',
#   'time',
#   'talk',
#   'compensation'],
#  ['thank'],
#  ['joined',
#   'silver',
#   'preferred',
#   'hear',
#   'customer',
#   'service',
#   'great',
#   'pity',
#   'misguide'],
#  ['work',
#   'call',
#   'jet',
#   'blue',
#   'mexico',
#   'address',
#   'fraud',
#   'alert',
#   'capital',
#   'line',
#   'rebooke'],
#  ['see', 'ppl', 'win', 'ticket', 'win'],
#  ['wait', 'book', 'hotel', 'nearby', 'send', 'hotel', 'manager', 'disbelief'],
#  ['go', 'round', 'amp', 'round', 'go', 'week'],
#  ['customer',
#   'service',
#   'phone',
#   'person',
#   'stone',
#   'wall',
#   'giant',
#   'middle',
#   'finger',
#   'paint'],
#  ['wtf', 'happen', 'pdx', 'late', 'flight', 'march', 'way', 'sfo'],
#  ['help', 'figure', 'correct', 'digit', 'confirmation', 'number'],
#  ['nice', 'talk', 'agent', 'catch', 'w', 'promotion', 'amp', 'hang'],
#  ['miss',
#   'set',
#   'hotel',
#   'flight',
#   'delay',
#   'sfo',
#   'hour',
#   'miss',
#   'wedding',
#   'festivity',
#   'friend',
#   '😞'],
#  ['thanks',
#   'good',
#   'stay',
#   'night',
#   'dallas',
#   'new',
#   'trial',
#   'detroit',
#   'atlanta',
#   'tomorrow',
#   'assume',
#   'cancelled',
#   'flightlations'],
#  ['thank'],
#  ['kinda',
#   'suck',
#   'earphone',
#   'jack',
#   'work',
#   'flight',
#   'want',
#   'look',
#   'future',
#   'passenger'],
#  ['late',
#   'flightr',
#   'complete',
#   'itinerary',
#   'change',
#   'lose',
#   'work',
#   'time',
#   'yeah',
#   'get',
#   'rebooke'],
#  ['delay',
#   'depart',
#   'bc',
#   'ur',
#   'flight',
#   'attendant',
#   'landing',
#   'take',
#   'hrs',
#   'gate',
#   'bag'],
#  ['land',
#   'day',
#   'late',
#   'flight',
#   'sleep',
#   'feel',
#   'sorry',
#   'woman',
#   'console',
#   'mother',
#   'die',
#   'night'],
#  ['thanx',
#   'rodeo',
#   'amp',
#   'yesterday',
#   'result',
#   'comm',
#   'u',
#   'count',
#   'status',
#   'bag',
#   'lose',
#   'amp',
#   'claim',
#   'file'],
#  ['amsterdam', 'ewr'],
#  ['year', 'think'],
#  ['easily', 'atlanta', 'need', 'ticket', 'help'],
#  ['face', 'palm', 'believe', 'hrs', 'hrs', 'sleep'],
#  ['redeem',
#   'travel',
#   'voucher',
#   'flight',
#   'reach',
#   'travel',
#   'agent',
#   'phone',
#   'hold',
#   'expire',
#   'hour'],
#  ['love', 'boarding', 'chicago', 'keepitmovin'],
#  ['week',
#   'maintenance',
#   'issue',
#   'flat',
#   'tire',
#   'flight',
#   'week',
#   'cancel',
#   'flighted',
#   'track',
#   'record',
#   'worst'],
#  ['ok',
#   'airport',
#   'help',
#   'customer',
#   'get',
#   'tell',
#   'flight',
#   'leave',
#   'till'],
#  ['thank',
#   'gate',
#   'agent',
#   'state',
#   'college',
#   'pa',
#   'able',
#   'early',
#   'flight',
#   'figure',
#   'early',
#   'connection'],
#  ['guy', 'hour', 'phone', 'hold', 'bc', 'volume', 'short', 'staffing'],
#  ['bad',
#   'flight',
#   'ground',
#   'crew',
#   'ignore',
#   'plane',
#   'miss',
#   'flight',
#   'cover',
#   'cost',
#   'hotel',
#   'den'],
#  ['yeah', 'haha', 'expensive', '😂', '😂', 'fun', 'destinationdragon'],
#  ['wish', 'fly', 'atlanta', 'soon'],
#  ['know', 'share', 'nasty', 'food', 'close', 'decent'],
#  ['dm', 'locator', 'code', 'thank'],
#  ['way', 'airport', 'will', 'fix', 'handle', 'show', 'problem', 'say', '…'],
#  ['miss',
#   'flight',
#   'attendant',
#   'delay',
#   'flight',
#   'prime',
#   'example',
#   'person',
#   'impact',
#   'people',
#   'hnl',
#   'iah',
#   'wastedtime'],
#  ['gate', 'agent', 'alavera', 'amazing'],
#  ['flight', 'morning', 'flight', 'thursday', 'monday', 'turn', 'tuesday'],
#  ['hey', 'miss', 'outbound', 'flight', 'use', 'return', 'ticket'],
#  ['partnership',
#   'hawaiian',
#   'live',
#   'earn',
#   'hawaiian',
#   'mile',
#   'fly',
#   'jetblue',
#   'add',
#   'jb',
#   'flight',
#   'booking',
#   'problems'],
#  ['flight',
#   'omagtden',
#   'actually',
#   'cancel',
#   'flightled',
#   'hold',
#   'hour',
#   'website',
#   'say',
#   'conflict',
#   'message'],
#  ['board',
#   'attendant',
#   'take',
#   'shoe',
#   'ampsock',
#   'desk',
#   'show',
#   'agent',
#   'foot',
#   'gross'],
#  ['employee',
#   'gate',
#   'jfk',
#   'tell',
#   'people',
#   'bag',
#   'fit',
#   'need',
#   'check',
#   'clearly',
#   'fit'],
#  ['hear',
#   'delta',
#   'offer',
#   'mile',
#   'frequent',
#   'flyer',
#   'bag',
#   'come',
#   'minute',
#   'landing',
#   'thought'],
#  ['fine', 'plunder', 'hard', 'earn', 'dollar', 'fine'],
#  ['stuck',
#   'airport',
#   'hour',
#   'standby',
#   'cuz',
#   'pilot',
#   'show',
#   'late',
#   'flight',
#   'pjs',
#   'amp',
#   'miss',
#   'connectin',
#   'flight',
#   'pj',
#   'tell',
#   'u',
#   'nyfw'],
#  ['ok', 'know', 'likely', 'book'],
#  ['cancel',
#   'flightle',
#   'flight',
#   'holiday',
#   'give',
#   'refund',
#   'ticket',
#   'phl',
#   'ewr'],
#  ['flight',
#   'hrs',
#   'delay',
#   'far',
#   'b',
#   'c',
#   'late',
#   'flight',
#   'crew',
#   'literally',
#   'wait',
#   'dinner',
#   'acc',
#   'honest',
#   'gate',
#   'agent'],
#  ['fleet', 'fleek', 'yall', 'better'],
#  ['thank'],
#  ['link', 'message', 'reply', 'itproblem'],
#  ['tripitpro',
#   'accurate',
#   'delay',
#   'dept',
#   'time',
#   'late',
#   'flightr',
#   'hear',
#   'curious'],
#  ['seriously',
#   'cat',
#   'dead',
#   'go',
#   'piss',
#   'thankful',
#   'evil',
#   'want',
#   'soul'],
#  ['auto', 'callback', 'wait', 'hold'],
#  ['step',
#   'shoot',
#   'step',
#   'acknowledge',
#   'customer',
#   'place',
#   'twitter',
#   'step',
#   'suck'],
#  ['rebooked',
#   'get',
#   'home',
#   'hour',
#   'late',
#   'flightr',
#   'plan',
#   'chance',
#   'bag',
#   'unhappytraveler'],
#  ['realize', 'wrong', 'departure', 'date', 'thank', 'make', 'change', 'easy'],
#  ['cancel',
#   'flighted',
#   'mileage',
#   'plus',
#   'award',
#   'reservation',
#   'day',
#   'mile',
#   'despite',
#   'agent',
#   'confirmation'],
#  ['thank', 'listen', 'compliant', 'right', 'thing', 'appreciate', 'work'],
#  ['finally', 'call', 'hasnt', 'spoken', 'like', 'bad', 'prank'],
#  ['book',
#   'pay',
#   'flight',
#   'denver',
#   'specific',
#   'time',
#   'meeting',
#   'fail',
#   'cause',
#   'weather'],
#  ['cxl',
#   'flight',
#   'dfw',
#   'cll',
#   'without',
#   'notice',
#   'treat',
#   'like',
#   'trash',
#   'phone',
#   'offer',
#   'compensation',
#   'wth'],
#  ['sorry', 'spam', 'awesome', 'vegas', 'help', 'absolutely', 'amazing'],
#  ['flt',
#   'lax',
#   'fll',
#   'ppl',
#   'sleep',
#   'would',
#   'disturb',
#   'flight',
#   'try',
#   'dl',
#   'movie'],
#  ['lga', 'san', 'diego'],
#  ['phone',
#   'hour',
#   'wait',
#   'customer',
#   'service',
#   'get',
#   'wrong',
#   'fight',
#   'information',
#   'cost',
#   'hour',
#   'trip',
#   'frustrating'],
#  ['check',
#   'right',
#   'mark',
#   'board',
#   'c',
#   'group',
#   'kid',
#   'age',
#   'dnt',
#   'want',
#   'split',
#   'sld'],
#  ['try', 'helpful', 'terrible', 'customer', 'service', 'airport'],
#  ['agent',
#   'will',
#   'hold',
#   'connection',
#   'arrive',
#   'late',
#   'flight',
#   'min',
#   'departure',
#   'time',
#   'min',
#   'late',
#   'flight',
#   'flt',
#   'gate',
#   'disappoint'],
#  ['cancelled',
#   'flights',
#   'flt',
#   'ewr',
#   'crew',
#   'tell',
#   'wife',
#   'amp',
#   'yr',
#   'old',
#   'ny',
#   'catch',
#   'yyz',
#   'good',
#   'customerservice',
#   'dead'],
#  ['phone', 'number', 'news'],
#  ['consider', 'past', 'midnight', 'hang', 'call', 'receive', 'service'],
#  ...]

# %% [markdown]
# making an array of all words

# %%
all_words = []
for re in revs:
    for word in re:
        all_words.append(word)
        
print(all_words)
# Out:
# ['mean', 'good', 'transcontinental', 'flight', 'pleasure', 'relief', 'wife', 'group', 'prev', 'flight', 'get', 'bump', 'reason', 'kid', 'group', 'nervous', 'sunday', 'flight', 'baltimore', 'boston', 'suggestion', 'need', 'boston', 'monday', 'flight', 'bna', 'rdu', 'excellent', 'crew', 'today', 'discount', 'volunteer', 'firefighter', 'absolutely', 'horrible', 'customer', 'service', 'person', 'suppose', 'immediately', 'disconnect', 'flyingitforward', 'fly', 'port', 'au', 'prince', 'haiti', 'help', 'go', 'earthquake', 'relief', 'effort', 'lot', 'far', 'good', 'step', 'denver', 'stop', 'portland', 'week', 'take', 'money', 'leave', 'strand', 'hour', 'home', 'rent', 'car', 'help', 'love', 'capt', 'joe', 'flight', 'bos', 'sfo', 'fun', 'seriously', 'doubt', 'sit', 'inside', 'gate', 'inconvenience', 'disaster', 'phone', 'bill', 'refuse', 'pay', 'flight', 'arrive', 'follow', 'flight', 'inform', 'hour', 'delay', 'pick', 'phone', 'flight', 'flight', 'delay', 'hour', 'la', 'mechanical', 'problem', 'handle', 'like', 'pro', 'toss', 'free', 'drink', 'hire', 'extra', 'customer', 'service', 'rep', 'minute', 'wait', 'time', 'ask', 'question', 'fly', 'airline', 'thank', 'thank', 'agent', 'boarding', 'atl', 'aus', 'leave', 'wallet', 'inbound', 'find', 'email', 'flight', 'wifi', 'promise', 'ground', 'crew', 'anotherdisappointment', 'stuck', 'nyc', 'flight', 'cancel', 'flightled', 'day', 'row', 'long', 'wait', 'time', 'phone', 'run', 'swa', 'help', 'time', 'count', 'people', 'awesome', 'work', 'long', 'hour', 'easy', 'sorry', 'twitter', 'help', 'ppl', 'u', 'hate', 'delay', 'u', 'amp', 'hold', 'hostage', 'goingforgreatnessfail', 'got', 'look', 'forward', 'finally', 'boom', 'hear', 'today', 'flight', 'tomorrow', 'arrive', 'home', 'pm', 'mean', 'day', 'work', 'follow', 'dm', 'thx', 'hold', 'min', 'attempt', 'receipt', 'show', 'change', 'fee', 'upcoming', 'flight', 'help', 'flight', 'buffalo', 'flight', 'cancel', 'flightled', 'purchase', 'ticket', 'united', 'card', 'priority', 'boarding', 'flight', 'lose', 'bag', 'amp', 'min', 'hold', 'tell', 'eventually', 'bag', 'completely', 'unacceptable', 'try', 'book', 'reservation', 'system', 'let', 'day', 'ridiculous', 'sure', 'sincere', 'apology', 'disappointing', 'customer', 'perspective', 'want', 'loyal', 'customer', 'option', 'try', 'check', 'min', 'flight', 'min', 'stonewall', 'employee', 'ba', 'flight', 'access', 'lounge', 'ord', 'hrs', 'hold', 'hour', 'minute', 'cust', 'service', 'help', 'literally', 'bad', 'flying', 'experience', 'life', 'fly', 'lot', 'navy', 'sister', 'flight', 'cancld', 'agent', 'call', 'hold', 'amp', 'discnct', 'help', 'shit', 'get', 'to', 'stop', 'rt', 'fleet', 'fleek', 'flight', 'love', 'redeem', 'point', 'little', 'year', 'old', 'historical', 'limit', 'great', 'callback', 'agent', 'disconnect', 'try', 'hold', 'wait', 'connectfor', 'fix', 'engine', 'flight', 'spend', 'night', 'airport', 'fly', 'home', 'tomorrow', 'thank', 'home', 'msy', 'tsa', 'precheck', 'agent', 'direct', 'people', 'photo', 'scan', 'rude', 'grab', 'push', 'child', 'possible', 'cancel', 'flight', 'reservation', 'online', 'bad', 'customer', 'service', 'provide', 'answer', 'drive', 'clt', 'airport', 'rude', 'amp', 'unacceptable', 'fail', 'live', 'person', 'speak', 'day', 'dividend', 'miles', 'wrongfully', 'take', 'mile', 'account', 'gold', 'force', 'pay', 'upgrade', 'open', 'seat', 'offer', 'gold', 'sapphire', 'bag', 'miss', 'ewr', 'dfw', 'stop', 'bna', 'refuel', 'bad', 'weather', 'try', 'plane', 'closer', 'dfw', 'cancel', 'flight', 'fleet', 'fleek', 'wtf', '😂', '😂', '😂', '😂', 'plane', 'hope', 'well', 'luck', 'return', 'flight', 'sunday', 'thank', 'want', 'fix', 'line', 'customer', 'care', 'team', 'currently', 'respond', 'inquiry', 'business', 'day', 'social', 'agency', 'nice', 'thing', 'fleet', 'fleek', 'wife', 'land', 'dc', 'ago', 'luggage', 'tell', 'b', 'deliver', 'hotel', 'pm', 'pm', 'luggage', 'fantastic', 'good', 'flight', 'service', 'stressful', 'morning', 'pay', 'check', 'bag', 'lax', 'madhouse', 'lot', 'angry ...

# %% [markdown]
# **tokenizing unique words**

# %%
from collections import Counter
counts = Counter(all_words)

sorted_counts = sorted(counts,key=counts.get,reverse=True)
word_to_int = {word:ii for ii,word in enumerate(sorted_counts,1)}

sz = len(word_to_int)

coded_revs = []
for review in revs:
    coded_revs.append([word_to_int[word] for word in review])

# %%
print(sz)
# Out:
# 9481

# %% [markdown]
# ENCODING LABELS

# %%
classes=[]
for lab in labels:
    if lab=='positive':
        classes.append([0,0,1])
    elif lab=='neutral':
        classes.append([0,1,0])
    else :
        classes.append([1,0,0])

# %% [markdown]
# MAX AND MIN LENGTH OF REVIEWS

# %%
review_lens = Counter([len(x) for x in coded_revs])
print("Zero-length reviews: {}".format(review_lens[0]))
print("Maximum review length: {}".format(max(review_lens)))
# Out:
# Zero-length reviews: 70
# Maximum review length: 43

# %% [markdown]
# REMOVING REVIEWS WITH 0 LENGTH

# %%
print('Number of reviews before removing outliers: ', len(coded_revs))

## remove any reviews/labels with zero length from the coded_revs list.

# get indices of any reviews with length 0
non_zero_idx = [ii for ii, review in enumerate(coded_revs) if len(review) != 0]

# remove 0-length reviews and their labels
coded_revs = [coded_revs[ii] for ii in non_zero_idx]
classes = np.array([classes[ii] for ii in non_zero_idx])

print('Number of reviews after removing outliers: ', len(coded_revs))
# Out:
# Number of reviews before removing outliers:  14640
# Number of reviews after removing outliers:  14570

# %% [markdown]
# FUNTION TO PAD REVIEWS (right)

# %%
def pad_features(reviews_ints, seq_length):
    ''' Return features of review_ints, where each review is padded with 0's 
        or truncated to the input seq_length.
    '''
    
    # getting the correct rows x cols shape
    features = np.zeros((len(reviews_ints), seq_length), dtype=int)

    # for each review, I grab that review and 
    for i, row in enumerate(reviews_ints):
        features[i, -len(row):] = np.array(row)[:seq_length]
    
    return features

# %%
seq_length = 15

features = pad_features(coded_revs, seq_length=seq_length)

# %% [markdown]
# Saving our features and classes data

# %%
from numpy import savetxt
savetxt('features.csv',features,delimiter=',')
savetxt('classes.csv',classes,delimiter=',')
